# %%
#sys libs
import os
import sys
import random
import warnings
warnings.filterwarnings("ignore")

#data manupulation libs
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from pandarallel import pandarallel
# Initialization
pandarallel.initialize()


#string manupulation libs
import re
import string
from string import digits
import spacy

#torch libs
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn
import torch.optim as optim
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
import json
 
with open('train_data1.json') as user_file:
  parsed_json = json.load(user_file)
x = 424714+80796
parsed_json
# parsed_json["English-Hindi"]["Train"][str(x)]
# Out:
# {'English-Bengali': {'Train': {'78683': {'source': 'Do not forget to visit the point where the Narmada flowing through the marble rocks interchanges its calmness and serenity into insouciance.',
#     'target': 'এই জায়গাগুলো দেখতে ভুলো না যেখানে নর্মদা নদী মার্বেল পাথরের পাহাড়ের মধ্য দিয়ে প্রবাহিত হচ্ছে এবং নিজের শান্তি ও সৌন্দর্যকে অনাসক্তিতে পরিণত করছে।'},
#    '78684': {'source': 'It is evident that the biggest cause of poverty is illiteracy .',
#     'target': 'এই কথা স্পষ্ট যে দরিদ্রতার বড় কারণ হল অশিক্ষা ।'},
#    '78685': {'source': 'The film was released theatrically on 12 April 2013.',
#     'target': 'চলচ্চিত্রটি ২০১৩ সালের ১২ই এপ্রিল প্রেক্ষাগৃহে মুক্তি পায়।'},
#    '78686': {'source': "is wyatt's birthday party at ten p. m.",
#     'target': 'অনিমেষ এর জন্মদিনের পার্টি রাত দশটায়'},
#    '78687': {'source': 'Apart from being used as an eatable, barley is also used in many other fields like industries and agriculture.',
#     'target': 'খাদ্যদ্রব্য ছাড়াও যব আরো বিভিন্ন ক্ষেত্রে যেমন শিল্প ও কৃষিতে ব্যবহার করা হয়।'},
#    '78688': {'source': 'Emperor Akbar got the State Museum constructed during his trip to Ajmer .',
#     'target': 'রাজকীয় সংগ্রহালয়ের নির্মাণ সম্রাট আকবর নিজের আজমের যাত্রার সময় করান ׀'},
#    '78689': {'source': 'initiate the music on the electronic playlist',
#     'target': 'ইলেক্ট্রনিক প্লেলিস্টের গানগুলো শুরু কর'},
#    '78690': {'source': 'Srinagar is at a distance of 305 kms from Jammu .',
#     'target': 'জম্মু থেকে শ্রীনগরের দূরত্ব হল ৩০৫ কি.মি. ৷'},
#    '78691': {'source': 'A devotee is chosen and a Karaga or a clay pot is placed on his head.',
#     'target': 'একটি ভক্ত বাছা হয়েছিল এবং একটি কারাগা অথবা একটি কাদা পাত্র তার মাথায় রাখা হয়েছিল।'},
#    '78692': {'source': 'The city is lined up with shops that have everything you need to stock up your kitchen shelves with.',
#     'target': 'শহরটিতে আপনার রান্নাঘর ভর্তি করার জন্য দোকান সাজানো আছে।'},
#    '78693': {'source': 'We can express our feelings and unwind ourselves in many different ways, share our feelings with those whom we know and trust.',
#     'target': 'আমরা আমাদের অনুভব প্রকাশ করতে পারি এবং নিজেদের হাঁপ ছাড়াই অনেক বিভিন্ন রীতিতে, আমরা যাদের চিনি এবং বিশ্বাস করি তাদের সাথে আমাদের অনুভব ভাগ করতে পারি।'},
#    '78694': {'source': 'It is used as a common picnic spot by the locals.',
#     'target': 'স্থানীয়দের দ্বারা এটা সাধারণ পিকনিকের জায়গা হিসাবে ব্যবহৃত হয়।'},
#    '78695': {'source': 'The best way to protect a newly born infant from infection is to lift it after cleaning ones hand with soap beforehand .',
#     'target': 'নবজাত শিশুকে সংক্রমণের হাত থেকে বাঁচাতে সবথেকে ভালো উপায় হল সাবান দিয়ে হাত ধুয়ে বাচ্চাকে কোলে নেওয়া ׀'},
#    '78696': {'source': 'The various categories of persons having different risk behaviours, who report to NICD for HIV testing are given pre-test, post test and continuum of counseling, as per individual case merit.',
#     'target': 'বিভিন্ন ধরনের লোকেরা যাদের নানা কার্জকলাপ আছে তারা এন আই সি ডি কে রিপোর্ট করে এইচ আই ভি টেষ্ট করার জন্য তাদের প্রি-টেষ্ট,পোষ্ট-টেষ্ট বা ক্রমাগত উপদেশ দেওয়া হয়ে জন প্রতি কেসের মেরিট দেখে।'},
#    '78697': {'source': 'The 2006 Varanasi bombings were a series of bombings that occurred across the Hindu holy city of Varanasi on 7 March 2006.',
#     'target': '২০০৬ সালের বারাণসী বোমা হামলা ছিল হিন্দুদের পবিত্র শহর বারাণসীতে ২০০৬ সালের ৭ই মার্চে ঘটা ধারাবাহিক বোমা হামলা।'},
#    '78698': {'source': 'One of the legends relating to Eklingji is that after killing Vrakshasur,Indra had meditated and prayed to Eklingji in penitence and to get rid of the curse.',
#     'target': 'একলিঙ্গজী সম্পর্কিত কিংবদন্তীগুলির একটি হল যে ভ্রক্ষাসুরকে বধ করার পর ইন্দ্র অভিশাপ থেকে মুক্তি পাওয়ার জন্য অনুশোচনায় ধ্যান করেছিলেন এবং একলিঙ্গজীর কাছে প্রার্থনা জানিয়েছিলেন।'},
#    '78699': {'source': 'good food', 'target': 'ভাল খাবার'},
#    '78700': {'source': 'This is thought to be very profitable in all important entertaining areas .',
#     'target': 'এটাকে অন্যান্য সমস্ত মনোরঞ্জক ক্ষেত্রেও লাভজনক মনে করা হয়েছে ৷'},
#    '78701': {'source': 'Among the dead were Black Kettle and his wife. The massacre is remembered as the Battle of the Washita, commemorated by Washita Battlefield National Historic Site.',
#     'target': 'মৃতদের মধ্যে ছিল ব্ল্যাক কেটল এবং তার স্ত্রী,এই বেপরোয়া হত্যাকান্ড হয়েছিল ওয়াহিটা যুদ্ধক্ষেত্রে ন্যাশানাল হিস্টোরিক সাইট।'},
#    '78702': {'source': 'There is an old palace and Shiva temple in Nadaun .',
#     'target': 'নাডৌনে একটা পুরানো মহল এবং একটা শিব মন্দির আছে ।'},
#    '78703': {'source': 'let me know about current traffic in carmen drive',
#     'target': 'ফটিকছড়ি বর্তমান ট্রাফিক সম্পর্কে আমাকে জানান'},
#    '78704': {'source': 'Many of the country’s top places to eat are nestled into remote, rural countryside, and even the tiniest villages boast gourmet farmers’ markets.',
#     'target': 'দেশের বিভিন্ন খাবার জায়গাগুলি আছে দূরের গ্রামে ,এছাড়া ছোটো ছোটো গ্রামগুলিতে আছে চাষীদের বাজার ।'},
#    '78705': {'source': 'Here one can see the processing of the world famous Darjeeling tea.',
#     'target': 'এখানে একজন বিশ্ব বিখ্যাত দার্জিলিং চায়ের প্রক্রিয়াকরণ দেখতে পারেন ।'},
#    '78706': {'source': 'It belongs to the Hinayana Buddhism sect in Maharashtra.',
#     'target': 'এটি মহারাষ্ট্রের হীনযান বৌদ্ধ সম্প্রদায়ের অন্তর্গত।'},
#    '78707': {'source': 'Reading in bright light in the night or working excessively is also dangerous for the eyes .',
#     'target': 'রাতে তীব্র আলোতে পড়াশোনা করা বা বেশি কাজ করাও হল চোখের পক্ষে ক্ষতিকারক ৷'},
#    '78708': {'source': 'Silk was used in weft designs and in the borders, whereas cotton was used in the body of the fabric.',
#     'target': 'ওয়েফট ডিজাইনে এবং পাড়ে সিল্ক ব্যবহার করা হত, আর কাপড়ের জমিতে সুতি ব্যবহার করা হত।'},
#    '78709': {'source': 'Some men may experience urinary frequency, urgency and incontinence but this will settle by the third month after surgery.',
#     'target': 'যাইহোক,যার ভাইরাস আছে পুনরায় সংক্রামিত হওয়ার সম্ভাবনা খুব কম কারণ শরীরে ভাইরাসের প্রতি প্রতিরোধ ক্ষমতা গড়ে ওঠে।'},
#    '78710': {'source': 'change the radio station',
#     'target': 'বেতার কেন্দ্র পরিবর্তন করুন'},
#    '78711': {'source': 'Various products and techniques were exhibited by total 504 stalls along with 129 big stalls in the farmers fair and agricultural industry exhibition .',
#     'target': 'বিগত তিন মাসে জনপদ চম্পাবত এবং পিথৌরাগড়ে অবস্থিত কৃষি বিজ্ঞান কেন্দ্রের বৈজ্ঞানিক উপদেশ সমিতির ( স্যাক ) বৈঠক লোহাঘাট কৃষি বিজ্ঞান কেন্দ্রে ২০১০-এর ২৫শে ফেব্রুয়ারী এবং গৈনা আঞ্চলি কৃষি বিজ্ঞান কেন্দ্রে ২০১০-এর ২৬শে ফেব্রুয়ারী আয়োজন করা হয় ৷'},
#    '78712': {'source': 'Most of them are of dietary origin.',
#     'target': 'বেশীর ভাগ গুলি আহারের কারনে হয়.'},
#    '78713': {'source': 'Every year in the month of Shravana (July-August), when the moon is full, thousands of devout pilgrims gather before Amarnath Cave in the picturesque Lidder Valley in Kashmir to offer their prayers to Lord Shiva.',
#     'target': 'প্রত্যেক বছর শ্রাবণ মাসের (জুলাই-আগস্ট) পূর্ণিমায় হাজার হাজার পুণ্যার্থী কাশ্মীরের অসাধারণ সুন্দর লিডার ভ্যালীর অমরনাথ মন্দিরের সামনে জড়ো হয় শিবঠাকুরের কাছে প্রার্থনা করার জন্য।'},
#    '78714': {'source': 'Lost people are calling to their friends in their language .',
#     'target': 'বিচ্ছিন্ন হয়ে যাওয়া লোক তাদের নিজেদের ভাষায় তাদের লোককে ডাকছে ׀'},
#    '78715': {'source': 'Same were given name of `` Yatuman `` in Awesta .',
#     'target': 'আবেস্তায় এদের নাম দেওয়া হয়েছে “ রাক্ষস ” ।'},
#    '78716': {'source': 'Other than this occurrence of cramps in a certain nerve fiber located in the lower part of the back is also a very important cause .',
#     'target': 'এ ছাড়াও একটি গুরুত্বপূর্ণ কারণ হল পিঠের নিচের অংশে স্থিত কোনও স্নায়ু তন্তুর ওপরে টান পড়া ৷'},
#    '78717': {'source': 'In the initial years fruit production is less but later on productivity increases gradually .',
#     'target': 'প্রথম বছরে ফল উত্পাদন কম হয় কিন্তু পরের বছরগুলিতে উত্পাদনক্ষমতা ধীরে - ধীরে বাড়তে থাকে ৷'},
#    '78718': {'source': 'Described by the Indian classical poet, Tagore as a "tear on the face of eternity", the Taj Mahal is undoubtedly the zenith of Moghal architecture and quite simply one of the world\'s most marvelous buildings.',
#     'target': 'ভারতীয় প্রাচীন কবি ঠাকুরের বিবরন "অনন্তকাল চোখের জল" তাজমহল নিঃসন্দেহে মোঘল স্থাপত্যের উজ্জ্বল বিন্দু এবং সাধারনভাবে পৃথিবীর সুন্দরতম স্থাপত্যের অন্যতম।'},
#    '78719': {'source': 'Therefore in the hilly areas of India we have started strawberry cultivation .',
#     'target': 'এই কারণে ভারতে পাহাড়ি অঞ্চলগুলিতে স্ট্রবেরির চাষ করা হচ্ছে ৷'},
#    '78720': {'source': 'The park also features the Marine Natural Study Center (tel. 0-7521-0664) and the Tourist Service Center.',
#     'target': 'হ্রদটির মধ্যস্থলে একটি পর্বত এটিকে দুই ভাগে বিভক্ত করেছে যার ফলে এর নাম হয়েছে থালে সং হং।'},
#    '78721': {'source': 'please set a reminder in my calendar for my meeting on march twenty five',
#     'target': 'আমার পঁচিশে মার্চের বৈঠকের জন্য অনুগ্রহ করে আমার ক্যালেন্ডারে একটি অনুস্মারক সেট করুন'},
#    '78722': {'source': 'Cross-sectional data were analyzed for 5692 children from Andhra Pradesh State in India and Vietnam sampled within "sites" (20 from each country) and then within "communities" (31 from Vietnam and 102 from India).',
#     'target': 'পরীক্ষাজোগ্য তথ্য পরীক্ষীত হয় ৫৬৯২ বাচ্চাদের জন্য ভারতের রাজ্য অন্ধ্রপ্রদেশের এবং ভিয়েতনামের বিভিন্ন স্থান(দেশ প্রতি ২০টি) এবং বিভিন্ন সামাজিক ক্ষেত্র(ভিয়েতনামের থেকে ৩১টি এবং ভারতের থেকে ১০২ টি) থেকে তথ্য গৃহিত হয়।'},
#    '78723': {'source': 'But then suddenly Shivaji tore his stomach with a Baghnakha .',
#     'target': 'কিন্তু তখনই শিবাজী তাঁর বাঘনখ দিয়ে আফজল খাঁর পেট ছিড়ে দেন ৷'},
#    '78724': {'source': 'Walk on the green lawns of this tomb and then drive towards the Akshardam temple, the temple that claims to be the bastion of Hinduism in India.',
#     'target': 'এই সমাধির সবুজ লনে হাঁটুন এবং পক্ষরধাম মন্দিরের দিকে গাড়ি চালান, যে মন্দিরটি ভারতে কড়া হিন্দুত্বের আখড়া হিসাবে প্রখ্যাত।'},
#    '78725': {'source': 'It is not irrelevant to say that Bharat Muni mentioned Samavakaar , Ihamrig , Dim Vyayog , Utsrishtikak , etc ten type of plays in Natyashashtra .',
#     'target': 'এখানে উল্লেখযোগ্য যে ভরত মুণি নাট্যশাস্ত্রে সমওকার , ইহামৃগ , ডিম , ব্যাযোগ , উত্সৃষ্টিকাক ইত্যাদি দশ প্রকারের নাটকের উল্লেখ করা হয়েছে ।'},
#    '78726': {'source': 'You will not get beer like this bar to drink in any other bar of Brussels .',
#     'target': 'এই ‘ বারের ’ মতো বিয়ার আপনি ব্রসেল্সের অন্য কোনো ‘ বারে ’ পাবেন না ׀'},
#    '78727': {'source': 'i want to eat something will you order food for me',
#     'target': 'আমি কিছু খেতে চাই আপনি কি আমার জন্য খাবার অর্ডার করবেন'},
#    '78728': {'source': 'Recognized by the Government of India and the Kerala Sports Council this institute is also training center of weaponry art called Kalariyapattu .',
#     'target': 'ইন্ডিয়ান স্কুল অফ মার্শিয়াল আর্টসে উষিচ্চিলের ( ম্যাসাজ ) জন্য ৬০০ বছরের পুরানো ` এণ্ণত্তোণি ` ( মালিশের ব্যবহৃত বস্তু ) আছে ৷'},
#    '78729': {'source': 'The people of New Zealand are also called by the name of Kiwi .',
#     'target': 'নিউজিল্যান্ডের লোকেদের কিউয়ি বলেও ডাকা হয় ৷'},
#    '78730': {'source': 'One day, the king expressed dissatisfaction with the food she had prepared.',
#     'target': 'একদিন, রাজা তাঁর তৈরি করা খাবার নিয়ে অসন্তোষ প্রকাশ করেন।'},
#    '78731': {'source': 'Because of its marvellous craft treasure Cracow was called as Polish Rome .',
#     'target': 'নিজের অতুলনীয় চমকপ্রদ শিল্পের জন্য ক্রাকোকে পোলিশ রোমা বলা হচ্ছিল ৷'},
#    '78732': {'source': 'Buy their beautiful handicrafts, taste their mouth-watering food and return with a treasure trove of pleasant memories.',
#     'target': 'তাদের সুন্দর হাতের কাজ,মুখে জল আনা খাবার কেনা এবং তা থেকে স্মৃতিতে ধরে রাখার মতো মূল্যবান সম্পদ পাওয়া যায়।'},
#    '78733': {'source': 'In modern times, the tarana is most commonly associated with the singer Amir Khan, who helped popularize it and researched its origins and the syllables used.',
#     'target': 'আধুনিক সময়ে, তারানাটি সাধারণত গায়ক আমির খানের সঙ্গে যুক্ত, যিনি এটিকে জনপ্রিয় করতে সাহায্য করেছিলেন এবং এর উৎস ও ব্যবহৃত শব্দাংশ নিয়ে গবেষণা করেছিলেন।'},
#    '78734': {'source': 'The true extent of the vectors is still unknown.',
#     'target': 'ভেক্টরের প্রকৃত মাত্রা এখনও অজানা।'},
#    '78735': {'source': 'Iron : - Is important for synthesis of green color ( chlorophyll ) and maintenance .',
#     'target': 'লোহা : গাছে সবুজ রঙের ( ক্লোরেফিল ) সংশ্লেষ এবং রক্ষণাবেক্ষণের জন্য প্রয়োজনীয় ৷'},
#    '78736': {'source': 'The Goans who would like to get the tourists stay in their house , we will assist them at all the levels starting from subsidy .',
#     'target': 'যে গোয়াবাসী নিজেদের বাড়িতে পর্যটকদের থাকতে দিতে চাইবেন তাদের আমরা সাবসিডি থেকে শুরু করে সব রকম সহায়তা করব ׀'},
#    '78737': {'source': 'Black pepper is used in the form of main ingredient in kadhi powder , chaat masala , pulao masala , chana masala , meat masala , sambhar masala etc. .',
#     'target': 'কারি মশলা , চাট মশলা , পোলাও মশলা , চানা মশলা , মিট মশলা , সাম্ভর মশলা ইত্যাদিতে গোলমরিচ প্রধান উপাদন হিসাবে ব্যবহৃত হয় ৷'},
#    '78738': {'source': 'In the eastern direction of the Red Fort there was a filth filled colony where there were Chor Bazar , open urinals and obstacled sewers .',
#     'target': 'সংস্কৃতি এবং পর্যটন মন্ত্রী হবার পরে যখন আমি লাল কেল্লাকে গভীরভাবে পর্যবেক্ষণ করার জন্য কেল্লায় যাই তখন আমি ওখানে অনেক জীর্ণ - শীর্ণ জিনিসপত্র দেখি ׀'},
#    '78739': {'source': 'The disease of filaria spreads because of the bite of mosquitoes named culecs pipians at night .',
#     'target': 'ফাইলেরিয়া রোগ রাতে কিউলেক্স পাইপিওনাস নামক মশা কামড়ালে হয় ׀'},
#    '78740': {'source': 'Both of these prevent nutritional anemia .',
#     'target': 'এই দুই উপাদান অপুষ্টিজনিত রক্তাল্পতা থেকে রক্ষা করে ৷'},
#    '78741': {'source': 'what time is it in new york city',
#     'target': 'ঢাকা শহরে কটা বাজে'},
#    '78742': {'source': 'Amblyopia is uncommon and, where present, rarely dense.',
#     'target': 'অ্যাম্বলিওপিয়া বিরল এবং যেখানে উপস্থিত, খুব কমই গাঢ়।'},
#    '78743': {'source': 'cancel my meeting tomorrow',
#     'target': 'আগামীকাল আমার meeting বাতিল করুন'},
#    '78744': {'source': 'Cut down sugar completely if you are a clear cut diabetic case.',
#     'target': 'যদি আপনার নিশ্চিতভাবে মধুমেহ থাকে আপনার সম্পূর্ণভাবে চিনি ত্যাগ করতে হবে।'},
#    '78745': {'source': 'The feathers impart substantial drag, causing the shuttlecock to decelerate greatly over distance.',
#     'target': 'পালকগুলি যথেষ্ট পরিমাণে টান প্রযুক্ত করে, যার ফলে দূরত্বের সাথে সাথে শাটলককের গতি অনেক হ্রাস পেয়ে যায়।'},
#    '78746': {'source': 'How much money do I have left in my Freecharge wallet?',
#     'target': 'আমার ফ্রিচার্জ ওয়ালেটে আমার কত টাকা বাকি আছে?'},
#    '78747': {'source': 'Symptom :- Heart becomes weak because of too much hard work or weakness .',
#     'target': 'লক্ষণ - অধিক পরিশ্রম অথবা ক্ষীণতার ফলে হৃদয় দুর্বল হয়ে পড়ে ৷'},
#    '78748': {'source': 'Participating in the Maha Shivratri festival is also a unique festival.',
#     'target': 'মহা শিবরাত্রি উৎসবে অংশগ্রহণ করাও এক অনন্য উৎসব।'},
#    '78749': {'source': 'According to historical records , this temple was built sometime in the 12th century.',
#     'target': 'শিব মন্দিরটি অবস্থিত ভারতের মধ্যপ্রদেশের ভোজপুরে যেটি ভারতের মধ্যপ্রদেশের মন্দিরগুলি পরিদর্শণকালে অবশ্যদর্শণীয়।'},
#    '78750': {'source': 'The ruins of ancient Patliputra inside the borders of the Patna City can be seen even today .',
#     'target': 'প্রাচীন পাটালিপুত্রের ভগ্নাবশেষ পাটনা শহরের সীমার ভেতর আজও দেখা যায় ׀'},
#    '78751': {'source': 'Rafi stated that he was only so keen to sing with Lata as she was with him.',
#     'target': 'রফি বলেন যে তিনি শুধু লাতার সাথে গান গাইতে খুব আগ্রহী ছিলেন কারণ তিনি তাঁর সাথে ছিলেন।'},
#    '78752': {'source': 'A very important study in Bangladesh has traced the relationship between risk of death and degrees of wasting and stunting.',
#     'target': 'বাংলাদেশের একটা খুবই গুরুত্বপূর্ণ পর্যবেক্ষনে রুপরেখা তৈরী করা হয়েছে মৃত্যুর ঝুঁকি এবং তীব্রতার মধ্যে মধ্যে সর্ম্পক বৃদ্ধি ব্যহত ও দুর্বলতার মতো।'},
#    '78753': {'source': 'With 3 wickets in the second innings, he took his maiden 10-wicket haul in first-class cricket, a feat he would later achieve twice in Test cricket.',
#     'target': 'দ্বিতীয় ইনিংসে ৩ উইকেট নিয়ে, প্রথম-শ্রেণীর ক্রিকেটে তিনি তাঁর সর্বপ্রথম ১০-উইকেট অর্জন করেন, যে কীর্তি তিনি পরে টেস্ট ক্রিকেটে দুইবার লাভ করেছিলেন।'},
#    '78754': {'source': 'You or the cashier can scan this bar code.',
#     'target': 'আপনি বা কোষাধ্যক্ষ এই বার কোডটি স্ক্যান করতে পারেন।'},
#    '78755': {'source': 'The Rajputs reciprocate the trust and arrange to have Padmini sit in a room at the edge of a water tank.',
#     'target': 'রাজপুতরা আস্থার প্রতিদান দেয় এবং পদ্মিনীকে একটি জলাধারের কিনারায় একটি ঘরে বসানোর ব্যবস্থা করে।'},
#    '78756': {'source': 'At the confluence with the Sutlej river, Harike barrage was constructed to divert the combined water flows of both rivers to irrigation canals to serve Rajasthan and Punjab areas.',
#     'target': 'শতদ্রু নদীর সঙ্গমস্থলে, রাজস্থান এবং পঞ্জাব অঞ্চলের সেচের খালে উভয় নদীর সম্মিলিত জলপ্রবাহকে নিয়ে যাওয়ার জন্য হরিকে বাঁধ নির্মাণ করা হয়েছিল।'},
#    '78757': {'source': 'Due to the tension started in the beginning of the January import of onion which is imported from the Pakistan via the way of the Wagha-Atari has got affected .',
#     'target': 'জানুয়ারীর শুরুতে এই উত্তেজনা চলাকালীন বাঘা - আটারীর রাস্তা দিয়ে পাকিস্তান থেকে পেঁয়াজের আমদানী প্রভাবিত হয়েছে ।'},
#    '78758': {'source': 'In case of water formation in the belly , on being tested by the tapping method the finger feels the pressure of the water .',
#     'target': 'পেটে জল হলে ও তা টিপে দেখলে আঙুলে যেন কোনো তরল পদার্থের ধাক্কা লাগছে বলে মনে হয় ׀'},
#    '78759': {'source': 'Some areas that are popular for climbing, for example in the United States and Australia, are also sacred places for indigenous peoples.',
#     'target': 'কিছু কিছু অঞ্চল যা পর্বতারোহণের জন্য জনপ্রিয়, উদাহরণস্বরূপ মার্কিন যুক্তরাষ্ট্র ও অস্ট্রেলিয়া, আদিবাসীদের জন্যও পবিত্র স্থান।'},
#    '78760': {'source': 'There are only 2-3 hotels in Auli wherein it is important to book rooms beforehand .',
#     'target': 'ঔলিতে দুটো - তিনটে হোটেল আছে - যেখানে আগে থেকে ঘর বুকিং করাতে হয় ৷'},
#    '78761': {'source': 'This is a good solution for those who can tolerate contact lenses.',
#     'target': 'যারা কন্টাক্ট লেন্স সহ্য করতে পারেন তাদের জন্য এটি একটি ভাল সমাধান।'},
#    '78762': {'source': 'Nausea starts occurring .', 'target': 'ঢেঁকুর ওঠে ৷'},
#    '78763': {'source': 'To see the culture of Rajasthani village in Jaipur there can be no better place than ` Chokhi Dhani ` .',
#     'target': 'জয়পুরে রাজস্থানী গ্রামের সংস্কৃতি দেখতে চাইলে চোখী ঢাণীর থেকে ভালো জায়গা আর হতে পারে না ׀'},
#    '78764': {'source': 'During this time, some martial arts systems devolved to the point that they became popular forms of martial art storytelling entertainment shows.',
#     'target': 'এই সময়ে, কিছু মার্শাল আর্ট পদ্ধতি এতটাই উন্নত হয়েছিল যে সেগুলি মার্শাল আর্ট গল্প বলার বিনোদনমূলক অনুষ্ঠানের জনপ্রিয় রূপ হয়ে উঠেছিল।'},
#    '78765': {'source': 'Cricket is the most popular sport in Maharashtra.',
#     'target': 'মহারাষ্ট্রের সর্বাধিক জনপ্রিয় খেলা হল ক্রিকেট।'},
#    '78766': {'source': 'Gauda Jagor is an impression of social life, that displays all the existing moods and modes of human characters.',
#     'target': 'গৌড় জাগোর সামাজিক জীবনের একটি ছাপ, যা মানব চরিত্রের সমস্ত বিদ্যমান মেজাজ এবং রীতিকে প্রদর্শন করে।'},
#    '78767': {'source': 'This is the reason that in this area idols related to Vaishnav , Shaiv , Buddhist , and Hindu religion are found .',
#     'target': 'কুর্কীহার আর আশেপাশের শিল্পকাররা যথেষ্ট সংখ্যায় মূর্তি নির্মাণ করতেন ৷'},
#    '78768': {'source': 'Baijnath has 5th place in Dwadash Jyotirlingas .',
#     'target': 'দ্বাদশ জ্যোর্তিলিঙ্গের মধ্যে বৈজনাথের স্থান ছিল পঞ্চম ৷'},
#    '78769': {'source': 'Indeed cinema and television are still images only , even it would be better to say that this is a chain of still images .',
#     'target': 'সিনেমা আর টেলিভিশনে , আসলে , স্থির চিত্র ( Still Images ) - ই হয় , বরং এটা বলা বেশি সঠিক হবে যে স্থির চিত্রের এটি এক শৃঙ্খলা ৷'},
#    '78770': {'source': 'Pasture grass seeds are very small and their sowing requires care and attention to detail; the few days of establishment are the most crucial for a new pasture.',
#     'target': 'ঘাসের বীজ খুবই ছোট ও এদের বপন প্রক্রিয়াটি যথেষ্ট যত্ন ও মনোযোগের দাবী রাখে;সন্সথাপনের প্রথম কটা দিন নতুন ফসলের ক্ষেত্রে খুবই গুরুত্বপূর্ণ।'},
#    '78771': {'source': '3/4 miles ahead of Chatti on the right side is 1 cave , 12/4 waterfalls 2 caves and a little field and at 2 miles from Haatchatti is Pipalkoti .',
#     'target': 'চটি থেকে ৩ / ৪ মাইল পর ডান দিকে ১টি গুহা , ১২ / ৪ ঝর্না , ২টি গুহা আর একটু খোলা মাঠ আর হাটচটি থেকে ২ মাইল পর পীপলকোটী রয়েছে ׀'},
#    '78772': {'source': 'has any personal emails come in yet',
#     'target': 'কোনো ব্যক্তিগত ইমেইল এখনও আসা আছে'},
#    '78773': {'source': 'There is vitamin E in more amount in it .',
#     'target': 'এতে বেশি মাত্রায় ভিটামিন ` এ ` পাওয়া যায় ৷'},
#    '78774': {'source': 'One sleeps well .', 'target': 'ভালো ঘুম আসে ৷'},
#    '78775': {'source': 'i can barely hear you olly',
#     'target': 'আমি খুব কমই আপনার কথা শুনতে পাচ্ছি'},
#    '78776': {'source': 'This year , the film Race has earned 100 crore rupees .',
#     'target': 'এই বছর রেস ২ সিনেমাটি একশো কোটি টাকা লাভ করেছে ।'},
#    '78777': {'source': 'The validated algorithms can present visually appealing graphics that assist in treatment decisions.',
#     'target': 'বৈধ গাণিতিক পরিভাষাগুলি দৃশ্যত আকর্ষণীয় চিত্রলেখ উপস্থাপন করতে পারে যা চিকিৎসার সিদ্ধান্তে আসতে সহায়তা করতে পারে।'},
#    '78778': {'source': 'Chefs Matthew has a special lunch for the value conscious too, priced at Rs. 178.',
#     'target': 'বাবুর্চি ম্যাথিউ এর একটি বিশেষ দুপুরের খাবার আছে যার মূল্য ১৭৮ টাকা।'},
#    '78779': {'source': 'The nearest rail head to reach Hemis High Altitude Park is in Jammu at a distance of 695 kilometres .',
#     'target': 'হেমিস হাড় অলটিটিউড রাষ্ট্রীয় উদ্যানে পৌঁছাবার জন্য নিকটতম প্রধান রেলস্টেশন ৬৯৫ কিলোমিটার দূরে জম্মুতে অবস্থিত রয়েছে ׀'},
#    '78780': {'source': 'Due to black spot over it fruits get decomposed.',
#     'target': 'কালো দাগ হয়ে গেলে ফল পচে যায় ৷'},
#    '78781': {'source': 'The International Eco-tourism Society defines eco-tourism as "responsible travel to natural areas that conserves the environment and improves the well-being of local people."',
#     'target': 'আন্তর্জাতিক ভূ পর্যটন সম্প্রদায় ভূ পর্যটন এর সংজ্ঞা দিয়েছেন "প্রাকৃতিক জায়গায় দায়িত্বশীল ভ্রমণ যা পরিবেশকে সংরক্ষণ কর এবং স্থানীয় লোকেদের উন্নতি কে উন্নত করে"।'},
#    '78782': {'source': 'i need to change my house lights color to blue',
#     'target': 'আমার ঘরের আলোর রঙ পরিবর্তন করে নীল করতে হবে'},
#    '78783': {'source': 'Due to the long period of tensions between his father and half-brother, Khurram began to drift closer to his father, and over time, started to be considered the de facto heir-apparent by court chroniclers.',
#     'target': 'তাঁর পিতা এবং সৎ-ভাইয়ের মধ্যে দীর্ঘ সময়ের চাপের কারণে, খুররম তাঁর বাবার কাছাকাছি আসতে শুরু করেছিলেন এবং সময়ের সাথে সাথে রাজসভার ঘটনাবলীতে তাঁকে প্রকৃত উত্তরাধিকারী হিসাবে বিবেচনা করা শুরু হয়েছিল।'},
#    '78784': {'source': 'These temples are built in triratha nagara style.',
#     'target': 'এই মন্দিরগুলি ত্রিরথ নগর শৈলীতে নির্মিত।'},
#    '78785': {'source': 'In Bangalore , monsoon stays from June to September .',
#     'target': 'ব্যাঙ্গালোরে জুন থেকে সেপ্টেম্বর পর্যন্ত মনসুন থাকে ৷'},
#    '78786': {'source': 'The month of June , 1999 in Uttar Pradesh was celebrated as the month of Malaria Mass Awareness .',
#     'target': 'উত্তরপ্রদেশে ১৯৯৯ সালের জুন মাস ম্যালেরিয়া জনজাগরণ মাস হিসাবে উদযাপন করা হয় ৷'},
#    '78787': {'source': 'He did not like to speak much .',
#     'target': 'প্রয়োজনের থেকে বেশী বলা পছন্দ করতেন না ৷'},
#    '78788': {'source': 'Often anemia , irregular menstrual period , complaints related to hair , nails and skin appear in women .',
#     'target': 'প্রায়ই মহিলাদের সঠিক ডায়েট না করার ফলে অ্যানিমিয়া , অনিয়মিত মাসিক ধর্ম , চুল , নখ আর ত্বক-সংক্রান্ত সমস্যা দেখা যায় ৷'},
#    '78789': {'source': 'And yet, miraculously, the denizens of this virile land have always resurrected and rebuilt their lives, confident and optimistic.',
#     'target': 'এবং এখনও পর্যন্ত আশ্চর্যভাবে, এই কর্মঠ ভূমির অধিবাসীরা সবসময় পুনরূজ্জীবিত করে এবং তাদের জীবন পুনর্নির্মিত, সুনিশ্চিত এবং আশাবাদী করে ।'},
#    '78790': {'source': "Ban Gu's Book of Han tells us the Kushans divided up Bactria in 128\xa0BC.",
#     'target': "বান গু-এর 'বুক অফ হান' আমাদের বলে যে কুশানরা ১২৮ খ্রিস্টপূর্বাব্দে ব্যাকট্রিয়াকে বিভক্ত করে।"},
#    '78791': {'source': 'The most prominent festival of Maharashtra is celebrated for ten days full of joy and merriment.',
#     'target': 'মহারাষ্ট্রের বিশিষ্টতম উৎসবটি আনন্দ উচ্ছাসে পূর্ণ এবং দশ দিন ধরে পালন করা হয় ।'},
#    '78792': {'source': 'find stock price for name',
#     'target': 'নামের জন্য স্টক মূল্য খুঁজুন'},
#    '78793': {'source': 'According to the point of view of natural doctors and dieticians food alone is the medicine .',
#     'target': 'প্রাকৃতিক চিকিত্সায় তো আহারকেই স্বাস্থ্য আর উপচার হেতু সর্বাধিক গুরুত্ব দেওয়া হয় ׀'},
#    '78794': {'source': 'will there be sunset at five thirty p. m. tomorrow',
#     'target': 'আগামীকাল কি সাড়ে পাঁচটায় সূর্যাস্ত হবে'},
#    '78795': {'source': 'The design motifs of these brocades are intricate floral and foliage patterns, kalga and bel and a string of upright leaves called jhalar is used to decorate sari pallas and dupattas.',
#     'target': 'ব্রকেডগুলির আকল্পের মূল প্রবনতা হল জটিল ফুল ও পাতার নকশা, কালগা ও বেল এবং শারির পাল্লা ও দুপাট্টা অলঙ্কৃত করার জন্য ঝালর অর্থাৎ ঋজু পাতার সমারহার ব্যাবহৃত হয়।'},
#    '78796': {'source': "what's next on my list",
#     'target': 'আমার তালিকার পরবর্তী কি'},
#    '78797': {'source': "Although Chhatrasal repeatedly sought Baji Rao's assistance, he was busy in Malwa at the time.",
#     'target': 'যদিও ছত্রশাল বারবার বাজি রাওয়ের সাহায্য চেয়েছিলেন, কিন্তু তিনি তখন মালওয়ায় ব্যস্ত ছিলেন।'},
#    '78798': {'source': 'create new contact with email',
#     'target': 'ইমেইল দিয়ে নতুন কন্ট্যাক্ট তৈরি করুন'},
#    '78799': {'source': 'Writings about chess theory began to appear in the 15th\xa0century.',
#     'target': '১৫শ শতাব্দীতে দাবা তত্ত্ব নিয়ে লেখালেখি শুরু হয়।'},
#    '78800': {'source': 'It is a cultural variety with a very large number of cultivars.',
#     'target': 'এটা কাল্টিভার্স-এর খুব বড় সংখ্যাযুক্ত একটি সাংস্কৃতিক বৈচিত্র্য।'},
#    '78801': {'source': 'Bandy in Sweden is famous for its "culture" – both playing bandy and being a spectator requires great fortitude and dedication.',
#     'target': 'সুইডেনে ব্যান্ডি তার "সংস্কৃতির" জন্য বিখ্যাত-ব্যান্ডি খেলা এবং দর্শক হওয়া, উভয়ের জন্যই প্রচুর সাহস এবং আন্তরিকতার প্রয়োজন।'},
#    '78802': {'source': 'open twitter send message',
#     'target': 'টুইটার খুলুন বার্তা পাঠান'},
#    '78803': {'source': 'Occurrence of seizures - in this various types of symptoms can occur together or separately .',
#     'target': 'অজ্ঞান হওয়া - এতে অনেক ধরণের লক্ষণ একসাথে বা আলাদা - আলাদাভাবে হতে পারে ৷'},
#    '78804': {'source': 'what is that song playing in the background',
#     'target': 'ব্যাকগ্রাউন্ডে যেটা কি গান বাজছে'},
#    '78805': {'source': 'play my downloaded music',
#     'target': 'আমার ডাউনলোড করা গানগুলো বাজাও'},
#    '78806': {'source': 'In blood of person infected with Hepatitis B this virus stays alive for 7 days .',
#     'target': 'হেপাটাইটিস-বি`তে সংক্রমিত ব্যাক্তির রক্তে এই ভাইরাস ৭ দিন পর্যন্ত জীবিত থাকে ৷'},
#    '78807': {'source': 'Celia Lottridge and Katherine Grier, both storytellers and educators, taught in the program with Joan.',
#     'target': 'সিলিয়া নাটরিডিশ এবং ক্যাথারলিন গিয়ার উভয় গল্পকথক এবং শিক্ষক জনের সঙ্গে এই অনুষ্ঠানে শিক্ষা দিয়েছিলেন।'},
#    '78808': {'source': 'Godhum SYM Punjika - various small piles were used to put up with grains like wheat and rupees - paisa used to hide in some piles .',
#     'target': 'জাফরান-পুংজিকা-গমের মতন শস্যের ছোট - ছোট অনেক গুচ্ছ লাগানো হত এবং কোন - কোনটার মধ্যে টাকা - পয়সাও লুকিয়ে রাখা হত ।'},
#    '78809': {'source': 'Because of the way it is spread, the hepatitis A virus tends to occur in epidemics and outbreaks.',
#     'target': 'যদি তোমার একবার হেপাটাইটিস এ হয়,সারাজীবন ব্যাপী অনাক্রম্যতা তৈরি হয় এবং তোমার আবার এই রোগ আর'},
#    '78810': {'source': 'Himalayas are adorned with beautiful valleys with enough slopes to be exploited positively for the sake of Adventure Sports.',
#     'target': 'হিমালয়ের পাহাড়গুলি সুসজ্জিত সুন্দর উপত্যকাগুলি দ্বারা যাদের অনেক ঢাল আছে যাদের সুন্দরভাবে কাজে লাগান যায় রোমাঞ্চময় ক্রীড়া গুলির জন্য।'},
#    '78811': {'source': 'speak louder', 'target': 'জোরে বলো'},
#    '78812': {'source': 'Maximum number of tourists like to visit the modern planetarium .',
#     'target': 'সবথেকে বেশি পর্যটক আধুনিক তারামণ্ডল কেন্দ্রে যেতে পছন্দ করেন ׀'},
#    '78813': {'source': 'Anshi National Park is spanning in an area of 250 square kilometres in North Kanada district .',
#     'target': 'অংশী রাষ্ট্রীয় উদ্যান কনাদা জেলায় ২৫০ বর্গ কিলোমিটার ক্ষেত্রের উপর বিস্তৃত রয়েছে ׀'},
#    '78814': {'source': 'Swelling on all the four sides of the chin of mouth .',
#     'target': 'মুখের ঠোঁটের চারপাশ ফুলে যাওয়া ৷'},
#    '78815': {'source': 'We call this iron ` haem iron ` .',
#     'target': 'এই আয়রনকে ` হিম আয়রন ` বলা হয় ৷'},
#    '78816': {'source': 'open the playlist', 'target': 'প্লেলিস্ট খুলুন'},
#    '78817': {'source': 'The cultivable area is 82 per cent of total geographical area and net area sown is 68.5 per cent of cultivable area.',
#     'target': 'চাষযোগ্য এলাকা মোট ভৌগোলিক এলাকার ৮২ শতাংশ এবং চাষযোগ্য এলাকার ৬৮.৫ শতাংশে মোট বপন করা হয়েছে।'},
#    '78818': {'source': 'Pathiramanal: According the mythology a young Brahmin dived into the Vembanad lake to perform his evening ablutions and the water made way for land to rise from below, thus creating the enchanting Island of Pathiramanal (sands of midnight).',
#     'target': 'পাথিরামানল: পুরাণবিষয়ক বিদ্যা অনুসারে তরুণ ব্রাহ্মণরা সন্ধ্যায় অভিসিঞ্চনের সঞ্চালন ভীমবানদ হ্রদের মধ্যে শূন্যে ঝাঁপ দেওয়া এবং জলের জন্য নীচে থেকে জমি কেটে পথ তৈরি, এইভাবে পাথারিয়ামানালের মুগ্ধ দ্বীপ (দ্বিপ্রহর মধ্যে বালি) নির্মাণ করেন।'},
#    '78819': {'source': 'Those who do mental work should definitely eat it .',
#     'target': 'বুদ্ধজীবি যারা তাদের এটার সেবন অবশ্য করা উচিত ৷'},
#    '78820': {'source': 'He was the first actor to win the Filmfare Best Actor Award and went on to win it a further seven times.',
#     'target': 'তিনি প্রথম অভিনেতা যিনি ফিল্মফেয়ার শ্রেষ্ঠ অভিনেতার পুরস্কার লাভ করেন এবং আরও সাতবার এই পুরস্কার অর্জন করেন।'},
#    '78821': {'source': 'If a director gets a good script then I will do it .',
#     'target': 'কোনো নতুন ডায়রেক্টর ভাল স্ক্রিপ্ট আনলে কাজ করব ।'},
#    '78822': {'source': 'An aspect of Hindustani music going back to Sufi times is the tradition of religious neutrality: Muslim ustads may sing compositions in praise of Hindu deities and vice versa.',
#     'target': 'সুফি যুগে ফিরে যাওয়া হিন্দুস্তানি সঙ্গীতের একটি দিক হল ধর্মীয় নিরপেক্ষতার ঐতিহ্য: মোসলমান ওস্তাদরা হিন্দু দেবদেবীর প্রশংসায় গান গাইতে পারেন এবং এর বিপরীতও ঘটে।'},
#    '78823': {'source': 'The caves of world famous Ajanta and Ellora is located at some distance from Aurangabad .',
#     'target': 'বিশ্বপ্রসিদ্ধ অজন্তা ঔরঙ্গাবাদ থেকে খানিক দূরেই অবস্থিত রয়েছে ׀'},
#    '78824': {'source': 'Patients with healed lesions may be severely disabled or may be able to resume normal life with restrictions in their physical activities.',
#     'target': 'রুগীরা সেরে ওঠা লেজিয়ন থেকে ভীষণ ভাবে পঙ্গু হয় অথবা সাভাবিক জীবন যাপন করতে পারে শারীরিক কর্মতে বিধি নিষেধ এনে.'},
#    '78825': {'source': 'The child nutrition researcher Dr. Theresa Nicholas in a study conducted with her colleagues has considered the above findings to be correct that juice consumers get many main nutrional elements in more quantity .',
#     'target': 'বাল পোষণ অনুসন্ধান কর্তা ডঃ থেরেসা নিকলাস নিজের সহযোগীদের সাথে করা একটি পর্যবেক্ষণে উক্ত রিপোর্টের সিদ্ধান্তকে সঠিক ধরেছেন যে জুস গ্রাহকরা বহু ধরনের পুষ্টি বহু মাত্রায় লাভ করে ׀'},
#    '78826': {'source': 'Jamaica is on storm watch, as after being hit by Hurricane Dean last month there is a possibility of more damage.',
#     'target': 'জামাইকা ঝড়ের নজরদারিতে রয়েছে, কারণ গত মাসে হারিকেন ডিনের আঘাতের পরে আরও ক্ষতির সম্ভাবনা আছে।'},
#    '78827': {'source': 'The genus Trifolium contains about 300 species; many are important in natural pasture and some twenty-five are cultivated.',
#     'target': 'ত্রিফোলিয়ামের জাতির মধ্যে ৩০০ টি প্রজাতি আছে যার মধ্যে বেশীরভাগই প্রাকৃতিক শষ্যভূমিতে চাষ হয় এবং প্রায় পঁচিশটি চাষ করা হয়।'},
#    '78828': {'source': 'It is a pleasant experience to stroll in the temple complex, which was built in 153A. D.',
#     'target': 'এটা আনন্দদায়ক অভিজ্ঞতা মন্দিরের চত্তরের চারিপাশে ঘুরে বেড়ানো,যেটি ১৫৩ খ্রীষ্টাব্দে তৈরি হয়েছিল।'},
#    '78829': {'source': 'In the 13th century, the city became a part of and, as some historians might claim, a center of the glorious Srivijaya Empire the kingdom that dominated the whole Malay Peninsula and much of Java.',
#     'target': '১৩শ শতাব্দীতে, নগরটি হয়ে উঠেছিল গৌরবময় শ্রীবিজয় সাম্রাজ্যের একটি অংশ এবং, যেমন কিছু কিছু ঐতিহাসিক দাবী করেন, সাম্রাজ্যের একটি কেন্দ্রও বটে, যে রাজ্য সমগ্র মালয় উপদ্বীপ ও জাভার অনেকটাই নিয়ন্ত্রণ করত।'},
#    '78830': {'source': 'If you’re in Krishnanagar, you must visit the artist’s colony in Ghurni. Here you’ll find yourself surrounded by amazing creations in clay-from life size sculptures to replicas of various fruits, spices and animals. They look quite bizarrely real.',
#     'target': 'যদি আপনি কৃষ্ণনগরে থাকেন তাহলে ঘুরনিতে শিল্পীদের কলোনি অবশ্যই আপনার দেখা উচিত। এখানে আপনি নিজেকে বিভিন্ন ফল, মশলা এবং জীবজন্তুদের অনুকরণে মাটির তৈরী আসল আকারের বিষ্ময়কর সৃষ্টির মধ্যে ঘেরা দেখতে পাবেন। তারা দেখতে পুরো বিচিত্রভাবে আসল।'},
#    '78831': {'source': 'T. pallidum pertenue has been identified in nonhuman primates and experimental inoculation of human beings with a simian isolate causes yaws-like disease.',
#     'target': 'টি. প্যালিডাম পারটেন্যু অমানবিক প্রাইমেটদের মধ্যে শনাক্ত করা হয়েছে এবং সিমিয়ান আইসোলেট দিয়ে মানুষের পরীক্ষামূলক ইনোকুলেশন ইয়াওস-সদৃশ রোগ সৃষ্টি করে।'},
#    '78832': {'source': 'Those who do not drink milk can take Shilajeet with hot water also .',
#     'target': 'যারা দুধ খান না , তারা গরম জলের সাথে শিলাজীত খেতে পারেন ৷'},
#    '78833': {'source': 'Tagore was a great friend of the royal family and his close relations had greatly influenced the royal family in the field of music.',
#     'target': 'রবীন্দ্রনাথ ঠাকুর ছিলেন একজন রাজপরিবারের বড় বন্ধু এবং রাজপরিবারে তার নিকট সম্পর্ক ছিল অতিশয় সঙ্গীত প্রভাবিত ।'},
#    '78834': {'source': 'The cause for the war between Harsha and Pulakeshin is not certain.',
#     'target': 'হর্ষ ও পুলকেশীর মধ্যে যুদ্ধের কারণ নিশ্চিত নয়।'},
#    '78835': {'source': 'They are more useful for cardiac patients.',
#     'target': 'হৃদয়সম্বন্ধীয় রোগীদের ক্ষেত্রে এটা বেশি উপযোগী।'},
#    '78836': {'source': 'Glissading should never be done on hard snow or ice in the morning time .',
#     'target': 'কঠিন বরফ আর আইসের ওপর সকালের সময়ে কখনও গ্লিসাডিং করা উচিত নয় ৷'},
#    '78837': {'source': 'MuktÄ\x81yi swarams are the swaram phrases (solfa passage) that occur after the anupallavi in tÄ\x81na varnams and which serve as the concluding part of the pÅ«rvanga (first part).',
#     'target': 'তান বর্ণমে অনুপল্লবীর পরে আসা এবং পূর্বাঙ্গ (প্রথম অংশ)-এর সমাপ্তি অংশের কাজ করা স্বরমের বাক্যাংশগুলি (স্বরলিপির অনুচ্ছেদ) হল মুক্তায়ি স্বরম।'},
#    '78838': {'source': 'Knowing the news will also help you connect with others in your industry.',
#     'target': 'এই খবরগুলির জ্ঞান আপনাকে আপনার শিল্পক্ষেত্রের অন্যান্যদের সঙ্গে সংযুক্ত হতেও সাহায্য করবে।'},
#    '78839': {'source': "In 2016, she presented current events show for TRT World in Istanbul, hosted Discovery Channel's Daily Planet in Canada and Sony ESPN's Premier Futsal in India.",
#     'target': '২০১৬ সালে, তিনি ইস্তানবুলে টিআরটি ওয়ার্ল্ডের জন্য বর্তমান ঘটনার অনুষ্ঠান উপস্থাপন করেন, কানাডায় ডিসকভারি চ্যানেলের ডেইলি প্ল্যানেট এবং ভারতে সোনি ইএসপিএন-এর প্রিমিয়ার ফুটসাল সঞ্চালনা করেন।'},
#    '78840': {'source': 'Local people can be seen promenading in the Chaugan till late night.',
#     'target': 'স্থানীয় মানুষদের নিশুতি পর্যন্ত ছাউগানের মধ্যে ব্যায়ামার্থ ভ্রমণ করতে দেখা যায় ।'},
#    '78841': {'source': 'Development of a national surveillance system for foodborne diseases which will provide consistent national reporting, facilitate collection of more extensive data on foodborne pathogens, and provide an opportunity for national trend analysis.',
#     'target': 'খাদ্য উদ্বুত রোগ এর জন্য জাতীয় নিরীক্ষন সংস্থা গঠন করা হয়েছে যা নিয়মিত জাতীয় প্রতিবেদন, কার্যকারী তথ্যসমূহ , জাতীয় প্রবনতা বিশ্লেষনের সুযোগ প্রদান করবে।'},
#    '78842': {'source': 'Because guilt-feeling comes in your mind only when you do n`t want to do that work but you do .',
#     'target': 'কারণ অপরাধ বোধ আপনার মনে তখনি আসে যখন আপনি এই কাজটিকে না করতে চেয়েও করে থাকেন ׀'},
#    '78843': {'source': 'how do i make peanut butter cookies',
#     'target': 'আমি কিভাবে চিনাবাদাম মাখন কুকিজ করতে পারি'},
#    '78844': {'source': 'With reference to news it means the main information will go in the beginning and the most subsidiary information will go at last .',
#     'target': 'সংবাদের এর অর্থ হল সর্বাপেক্ষা মুখ্য তথ্য শুরুতে দেওয়া হবে আর সর্বাপেক্ষা গৌণ তথ্য শেষে ।'},
#    '78845': {'source': 'Important religious places and Ghats along the course of the river, starting from its origin at Narmada Kund at Amarkantak hill.',
#     'target': 'অমরকন্টক পাহাড়ের নর্মদা কুণ্ড থেকে শুরু করে নদীর গতিপথ বরাবর গুরুত্বপূর্ণ ধর্মীয় স্থান এবং ঘাট রয়েছে।'},
#    '78846': {'source': 'please play any joy division album',
#     'target': 'যে কোন মাইলসের অ্যালবাম বাজাও'},
#    '78847': {'source': 'Tourists other than Indian are not allowed to import or export the Indian currency.',
#     'target': 'ভারতীয় ছাড়া অন্য ভ্রমণার্থীদের ভারতীয় মুদ্রা আমদানী বা রপ্তানী করার অনুমতি নেই।'},
#    '78848': {'source': 'The state tree is the Sal found in Bastar division.',
#     'target': 'রাষ্ট্রীয় গাছ হল শাল যা বস্তার অংশে পাওয়া যায়।'},
#    '78849': {'source': 'So do not panic when you get fever.',
#     'target': 'হলে ভীত হওয়ার প্রয়োজন নেই।'},
#    '78850': {'source': 'how long does train a take to get to station b.',
#     'target': 'স্টেশন ক থেকে স্টেশন খ যেতে ট্রেন কতক্ষণ সময় নেয়'},
#    '78851': {'source': 'In order to exact his revenge, the police officer reveals the truth in court, and Saulaal along with his cronies are sent to jail.',
#     'target': 'তার যথাযথ প্রতিশোধ নেওয়ার জন্য, পুলিশ অফিসার আদালতে সত্য প্রকাশ করে এবং সওলালকে তার সহযোগীদের সাথে কারাগারে পাঠানো হয়।'},
#    '78852': {'source': 'What do people not do for beauty , some give time to dieting or some makes rounds of the beauty parlor .',
#     'target': 'সৌন্দর্যের জন্য লোকেরা কিনা করেন , কেউ ডায়েটিং-এ সময় দেন বা কেউ পার্লারে ঘুরে বেড়ান ৷'},
#    '78853': {'source': 'With this you will get relief from the prominent symptoms of fever in the morning , like sneezing , running nose , itching in the eyes and lack of sleep .',
#     'target': 'এর থেকে সকালে হওয়া জ্বরের লক্ষণ , যেমন হাঁচি পাওয়া , নাক দিয়ে জল পড়া , চোখ চুলকানো ও ঘুম না হওয়ার সমস্যাগুলো থেকে আরাম পাবেন ৷'},
#    '78854': {'source': "His birthday is celebrated as Children's Day in India.",
#     'target': 'তাঁর জন্মদিনকে ভারতে শিশু দিবস হিসেবে পালন করা হয়।'},
#    '78855': {'source': 'The film has proved to be helpful in attracting the youngsters towards sports as it is based on Milkha Singh , the international athlete award winner .',
#     'target': 'এই সিনেমা দেশের আন্তর্জাতিক অ্যাথলিট পদক বিজয়ী মিলখা সিংহকে নিয়ে তৈরী হওয়ার ফলে নবীন প্রজন্মকে খেলার দিকে আকর্ষিত করতে সাহায্যকারী বলে প্রমাণিত হচ্ছে ৷'},
#    '78856': {'source': 'Excreta ( sawdust ) of brown color is seen all around the tree infested with this insect in the form of round balls .',
#     'target': 'এই পোকার দ্বারা আক্রান্ত গাছের চারপাশে ধূসর রঙের নিষ্কাশিত মল ছোট গোল আকারে দেখা যায় ৷'},
#    '78857': {'source': 'Devaraja had started vesting more military authority in his brother, and in 1749 Nanjaraja marched the Mysorean army in support of Nasir Jung.',
#     'target': 'দেবরাজ তাঁর ভাইয়ের ওপর আরও সামরিক অধিকার ন্যস্ত করতে শুরু করেছিলেন, এবং ১৭৪৯ সালে নঞ্জরাজা মহীশুরীয় সেনাবাহিনীকে নাসির জংয়ের সমর্থনে এগিয়ে নিয়ে গিয়েছিলেন।'},
#    '78858': {'source': 'It contains potassium and sodium which keeps the ` blood pressure ` of body controlled .',
#     'target': 'এটি পটাশিয়াম এবং সোডিয়ামে সমৃদ্ধ যা শরীরের `ব্লাড প্রেশার`কে নিয়ন্ত্রণে রাখে ৷'},
#    '78859': {'source': "It's likely that more Americans are allergic to peanuts than any other food.",
#     'target': 'এটা প্রত্যাশিত যে বেশিরভাগ আমেরিকানরা অন্যান্য খাদ্যের চেয়ে চীনাবাদামের প্রতি বেশী এলার্জি রয়েছে।'},
#    '78860': {'source': 'send mail to bubbles i want to meet her tomorrow at two p. m. in office',
#     'target': 'রফিকের কাছে মেইল \u200b\u200bপাঠাও আমি আগামীকাল অফিসে দুপুর দুইটায় তার সাথে দেখা করতে চাই'},
#    '78861': {'source': 'book me a single train ticket traveling to new york city leaving after nine am',
#     'target': 'আমাকে ঢাকা শহরে যাওয়ার জন্য একটি ট্রেনের টিকিট বুক করুন যা সকাল নয়টার পর ছেড়ে যায়'},
#    '78862': {'source': 'Malhar Rao Holker, the founder of the dynasty and his daughter in law, Ahilya Bai Holkar became the most famous of the Holkers, Ahilay bai being one of the most famous Indian rulers.',
#     'target': 'মালহার রাও হোল্কার, যিনি হোলকার বংশের প্রতিষ্ঠাতা ও তার বৌমা অহল্যা বাঈ হোল্কার সবচেয়ে নামকরা।'},
#    '78863': {'source': 'PÄ\x81lÄ«tÄ\x81á¹‡Ä\x81 is a city in Bhavnagar district, Gujarat, India.',
#     'target': 'পালিতানা হল ভারতের গুজরাট রাজ্যের ভাবনগর জেলার একটি শহর।'},
#    '78864': {'source': 'High quality seed gives up to 20-25 % more produce than the ordinary seed .',
#     'target': 'উত্তম গুণমানযুক্ত বীজ সাধারণ বীজের তুলনায় ২০ থেকে ২৫ শতাংশ বেশী কৃষি উত্পাদন দেয় ৷'},
#    '78865': {'source': 'According to the sources of the forest department last year a total of 8.93 lac birds of 168 types had reached Chilka .',
#     'target': 'বন বিভাগের সূত্র অনুযায়ী , গত বছরে ১৬৮ ধরণের মোট ৮.৯৩ লাখ পাখি চিলকাতে এসেছে ৷'},
#    '78866': {'source': 'It takes years for blood pressure to develop and it takes months to control it and reverse the process and set right the damages caused by blood pressure to the body.',
#     'target': 'রক্তচাপের উন্নতিতে ক্যেক বছর নেয় এবং এর নিয়ন্ত্রনে কয়েক মাস সময়নেয় এবং রক্তচাপের প্রভাবে শরীরের ক্ষতি পূর্ণ করে।'},
#    '78867': {'source': 'For the Buddhists followers of the religion formulated by Buddha from the world over , Bodhgaya is the purest pilgrimage .',
#     'target': 'বুদ্ধের দ্বারা প্রতিপাদিত ধর্ম পথে চলা সারা বিশ্বের “ বৌদ্ধদের ” কাছে বোধগয়া হল একটি পবিত্রতম তীর্থ ׀'},
#    '78868': {'source': 'If you there from Galle then Mirisa falls in between .',
#     'target': 'গল থেকে ওখানে গেলে মাঝে মিরিসা পড়ে ৷'},
#    '78869': {'source': 'Before this in this region only one crop was cultivated in three - four years .',
#     'target': 'এর আগে এই অঞ্চলে তিন - চার বছরে কেবল একটি ফসলই চাষ করা যেত ৷'},
#    '78870': {'source': 'You feel stomach bloated with sort of water all the time .',
#     'target': 'পেটে সবসময় জল ভরা মনে হয় ৷'},
#    '78871': {'source': 'Through the style of placing the stoll on the head and changes in the facial expression the mentality of the characters is partially expressed .',
#     'target': 'মাথায় ওড়না ধারণের কায়দা এবং মুখ্যমুদ্রার পরিবর্তনের মাধ্যমে চরিত্রের মনোবৃত্তির আংশিকভাবে অভিব্যক্তি ঘটে ।'},
#    '78872': {'source': 'The biggest share of the total food grain production of our country comes from this crop system .',
#     'target': 'আমাদের দেশে মোট খাদ্যান্ন উত্পাদনের সবথেকে বড় অংশ এই ফসল প্রণালী থেকে আসে ৷'},
#    '78873': {'source': 'If you use any medicine for allergy , asthama , joint pain even then you can be afflicted with Kaanchbind .',
#     'target': 'যদি আপনি অ্যালার্জি , হাঁপানি , গাঁটের ব্যাথার জন্য কোনও ওষুধ খান তাহলেও আপনার কাঁচবিন্দু হতে পারে ৷'},
#    '78874': {'source': "what's the latest in my social media",
#     'target': 'আমার সামাজিক মিডিয়া সর্বশেষ কি'},
#    '78875': {'source': 'Nature and mythology has gifted Amarkantak with the heritage diverse wealth .',
#     'target': 'অমরকন্টকের প্রকৃতি আর পৌরাণিকতা বিবিধ সম্পদের অধিকারী করেছে ׀'},
#    '78876': {'source': 'open reply', 'target': 'খোলা উত্তর'},
#    '78877': {'source': 'Jawahar Balabhavana- Bal Bhavan, whizzes you into Childhood.',
#     'target': 'জওহর বালভবন, যা তোমাকে বাল্যকালে প্রবেশ করিয়ে দিবে।'},
#    '78878': {'source': 'The ball is out of bounds if it touches a boundary line, or touches any player or object that is out of bounds.',
#     'target': 'যদি বল সীমারেখা স্পর্শ করে, বা কোনও খেলোয়াড় বা বস্তুকে স্পর্শ করে যা সীমানার বাইরে, তবে এটিকে সীমানার বাইরে বলে বিবেচনা করা হয়।'},
#    '78879': {'source': 'Apart from these wines a wine named Kailatak Madhu also mentioned in Mahabharata .',
#     'target': 'মহাভারতে উন্নত প্রকারের মদ ছাড়াও কৈলাতক মধু নামের এক প্রকারের সুরার উল্লেখ পাওয়া যায় ৷'},
#    '78880': {'source': 'The mouth of Mahanadi is in Darjeeling and this meets with the Ganga river in West Bengal .',
#     'target': 'মহানদীর উদ্ভব স্থল হল দার্জিলিং আর এটি পশ্চিম বাংলায় এসে গঙ্গা নদীর সাথে মেশে ׀'},
#    '78881': {'source': 'Notify 3 days in advance for all auto-payments in PayZapp .',
#     'target': 'পেজ্যাপ -এ সমস্ত স্বয়ংক্রিয় অর্থপ্রদানের জন্য ৩ দিন আগে অবহিত করুন।'},
#    '78882': {'source': 'start a small chart',
#     'target': 'একটি ছোট তালিকা শুরু করুন'},
#    '78883': {'source': 'An Albanian girl who publicly exposed alleged corruption in the Vlore Police Department has died violently.',
#     'target': 'একজন আলবেনিয়ান মেয়ে যে ভ্লোর পুলিশ ডিপার্টমেন্টের কথিত দুর্নীতি প্রকাশ্যে নিয়ে এসছিল, সহিংসভাবে মারা গেছে।'},
#    '78884': {'source': 'It is the 81st birthday of Meena Kumari on 1st August .',
#     'target': '১লা আগস্ট মীনা কুমারীর ৮১তম জন্মদিন ।'},
#    '78885': {'source': 'is steph curry married',
#     'target': 'আবু সালেহ বিবাহিত'},
#    '78886': {'source': 'In the 1957 Indian general election, Vajpayee contested elections to the Lok Sabha, the lower house of the Indian Parliament.',
#     'target': '১৯৫৭ সালের সাধারণ নির্বাচনে, বাজপেয়ী ভারতীয় সংসদের নিম্নকক্ষ, লোকসভায় নির্বাচিত হওয়ার জন্য লড়েন।'},
#    '78887': {'source': 'Lingmala Waterfalls (6 Km) -- Lingmala waterfalls present an enthralling sight of cascading water as it scatters from atop a steep cliff into thin silver streaks, often encircled by rainbow colors.',
#     'target': 'লিঙ্গমালা জলপ্রপাত ( ৬ কিমি) -- লিঙ্গমালা জলপ্রপাত প্রদর্শন করে এক বিমুগ্ধকর বিশালাকার জলপ্রপাতের দৃশ্য যখন সরু অনিয়মিত বিন্দুর রেখার মত ছড়িয়ে যায় ওপরের খাড়া পাহাড় থেকে, কখনও বা ঘিরে থাকত রামধনুর সাত রঙে।'},
#    '78888': {'source': 'The population ( in 2001 AD ) of Nagaland was 1988636 .',
#     'target': 'নাগাল্যান্ডের জনসংখ্যা ( ২০০১ সালে ) ১৯৮৮৬৩৬ ছিল ׀'},
#    '78889': {'source': 'This can be an expected interest rate if you are unsure.',
#     'target': 'এটি একটি প্রত্যাশিত সুদের হার হতে পারে, যদি আপনি নিশ্চিত না হন।'},
#    '78890': {'source': 'Aa Aab Laut Chale presented in 1998 is the last film of this prestigious banner .',
#     'target': '১৯৯৮ সালে প্রর্দশিত আ অব লট চলে এই প্রতিষ্ঠিত ব্যানারের শেষ সিনেমা ।'},
#    '78891': {'source': 'The edible seed is a grain (caryopsis) 5–12 mm (0.20–0.47 in) long and 2–3 mm (0.079–0.118 in) thick.',
#     'target': 'এর ভোজ্য বীজ দানাগুলি(ক্যারিওপসিস)দৈর্ঘ্যে ৫-১২ মিঃ মিঃ(০.২০-০.৪৭ ইঞ্চি) এবং প্রস্থে ২-৩ মিঃ মিঃ(০.০৭৯-০.১১৮ ইঞ্চি) হয়।'},
#    '78892': {'source': 'Impetigo is treated with antibiotics that kill the bacteria.',
#     'target': 'ছোঁয়াচে ঘা হয় ব্যবহার সহকারে অয়ান্টিবায়োটিক ঐ মারা the ব্যাকটেরিয়া ।'},
#    '78893': {'source': 'Vaccine must be administered after birth as early as possible .',
#     'target': 'জন্ম হওয়ার পর যত শীঘ্র সম্ভব টীকা দেওয়া উচিত ৷'},
#    '78894': {'source': 'With a shaky stomach the man is ready to fight or run.',
#     'target': 'অস্থির পাকস্থলী যুক্ত কোনও ব্যাক্তি লড়বার অবস্থায় থাকে না।'},
#    '78895': {'source': 'In the years that followed, garbage from the city was not disposed of properly.',
#     'target': 'পরবর্তী বছরগুলিতে শহরের আবর্জনা সঠিকভাবে বর্জন করা হয়নি।'},
#    '78896': {'source': 'There are several microbrewery festivals throughout the year as well.',
#     'target': 'এছাড়াও বেশ কয়েকটি ছোট ছোট মদ্যপানের উৎসব অনুষ্ঠিত হয় সারা বছর ধরে।'},
#    '78897': {'source': 'It is now known as Tulsi Mandir.',
#     'target': 'ইহা এখন তুলসি মন্দির হিসাবে জানা যায়।'},
# ...
#    '1070363': {'source': 'the song playing now is released by which artist',
#     'target': 'ఇప్పుడు ప్లే అవుతున్న పాటను ఏ ఆర్టిస్ట్ విడుదల చేసారు'},
#    '1070364': {'source': 'Iron being in excess can be fatal , hence to expel it from body injections of ferrol are given regularly .',
#     'target': 'ఐరన్ ఎక్కువగా ఉండటం అపాయకరం అవుతుంది , మరియు దీనిని శరీరం నుండి తొలగించడానికి డిస్\u200dఫెరాల్ ఇంజక్షన్ క్రమపద్ధతిలో ఇస్తారు .'},
#    '1070365': {'source': 'remove the event from monday',
#     'target': 'సోమవారం నుండి ఈవెంట్\u200c ను తీసివేయండి'},
#    '1070366': {'source': 'increase the volume a bit',
#     'target': 'వాల్యూమ్ కొద్దిగా పెంచండి'},
#    '1070367': {'source': 'put on be warned by tech nine',
#     'target': 'టెక్ నైన్ ద్వారా హెచ్చరించాలి'},
#    '1070368': {'source': 'activate the robot vacuum',
#     'target': 'రోబోట్ వాక్యూమ్\u200cని యాక్టివేట్ చేయండి'},
#    '1070369': {'source': 'On journeys children want to eat something after every little while .',
#     'target': 'యాత్రలో పిల్లలు కొంచెం-కొంచెం సమయం తరువాత ఏదో ఒకటి తినాలనుకొంటారు .'},
#    '1070370': {'source': 'Two people, one male and one female were shot and killed at West Ambler Johnston Hall, in what police initially were led to believe was a domestic incident.',
#     'target': 'వెస్ట్ ఏంబ్లర్ జాన్స్టన్ హాల్ వద్ద ఇద్దరు వ్యక్తులు, ఒక పురుషుడు మరియు ఒక స్త్రీ కాల్చి చంపబడ్డారు, పోలీసులు మొదట ఇది గృహ సంఘటనగా నమ్మారు.'},
#    '1070371': {'source': 'If you are planning a future together, make sure to include your significant other in your planning.',
#     'target': 'మీరు కలిసి భవిష్యత్తుకై ప్రణాళిక చేస్తున్నట్లయితే, మీ ప్రణాళికలో మీ జీవితభాగస్వామిని కలుపుకోండి.'},
#    '1070372': {'source': 'As of the 2011 Census of India, Namchi has a population of 12194.',
#     'target': '2011 భారత జనాభా లెక్కల ప్రకారం, నామ్చిలో 12,194 జనాభా ఉంది.'},
#    '1070373': {'source': 'To stay , advance reservations needs to be done in various rest houses .',
#     'target': 'విభిన్న విశ్రాంతి గృహాలలో ఉండటానికి అగ్రీమ్ ముందుగా చేయించుకోవాలి .'},
#    '1070374': {'source': 'Now if we talk especially about the lover , then chocolate can help in the firmness while erection .',
#     'target': 'ఇప్పుడు ముఖ్యంగా విషయం గురించి ప్రేమతో చర్చిస్తే కనుక చాక్లెట్ ఇరేక్షన్ లో తగ్గుదల రావడంలో సహాయపడుతుంది .'},
#    '1070375': {'source': 'Sambhaji was also granted territory in Berar for revenue collection.',
#     'target': 'పన్ను సేకరణ కోసం సంభాజీకి బెరార్ లో భూభాగం కూడా మంజూరు చేయబడింది.'},
#    '1070376': {'source': 'He not only knew singing but apart from singing he was also learning other auxiliary instruments .',
#     'target': 'వారికి కేవలం గానజ్ఞానమే కాదు , గానంతోపాటు వారు ఇతర సహకారవాద్యాల పరిజ్ఞానం కూడా పొందుతూ ఉండేవారు .'},
#    '1070377': {'source': 'Rajasthan is also the biggest wool-producing state in India and the main opium producer and consumer.',
#     'target': 'రాజస్థాన్ భారతదేశంలో అతిపెద్ద ఉన్ని ఉత్పత్తి చేసే రాష్ట్రం మరియు ప్రధాన నల్లమందు ఉత్పత్తి మరియు వినియోగదారు కూడా .'},
#    '1070378': {'source': 'Major irrigation canals were built after millions of people died each in a series of major famines in the 19th century in British India.',
#     'target': '19వ శతాబ్దంలో బ్రిటిష్ ఇండియాలో భారీ కరువుల వరుసలో లక్షలాది మంది మరణించిన తరువాత ప్రధాన నీటిపారుదల కాలువలు నిర్మించబడ్డాయి.'},
#    '1070379': {'source': 'The surface of the mirror is completely safe no negative energy could break it .',
#     'target': 'దర్పణం కలిగిన పైభాగం పూర్తి స్థాయిలో సురక్షితంగా ఉంది ఇది ఎలాంటి వ్యతిరేక శక్తి కూడా విరుగగొట్టలేదు .'},
#    '1070380': {'source': 'Other than chaubola the other important metres used in this era were - daud , khyaal , lavani , jhulana , kada and barahamasa .',
#     'target': 'చౌబోలేగాకుండ ఈ యుగంలో ఉపయోగింపబడుతున్న ఛందస్సులు దౌడ్, ఖ్యాల్, లావనీ, ఝూలనా, కడా మరియు బారహమాసా .'},
#    '1070381': {'source': 'Normally shoulders of both arms get jammed else stiffness occurs in them because of which patients can not even comb their hair .',
#     'target': 'సామాన్యంగా రెండు భుజాలు అతుక్కొనిపోతాయి లేక ఇవి బిగుసుకుపోతాయి ఈ కారణం వలన రోగి వెంట్రుకలలో దువ్వెన కూడా పెట్టలేడు .'},
#    '1070382': {'source': "The Indian Naval Academy, located at Ezhimala, is Asia's largest, and the world's third-largest, naval academy.",
#     'target': 'ఎజిమలాలో ఉన్న ఇండియన్ నావల్ అకాడమీ ఆసియాలోనే అతిపెద్ద మరియు ప్రపంచంలోనే మూడవ అతిపెద్ద నావల్ అకాడమీ.'},
#    '1070383': {'source': 'According to the Agriculture ministry in the current Rabi season , by Friday , sowing has been done in 567 hectares of land .',
#     'target': 'వ్యవసాయశాఖను అనుసరించి ప్రస్తుత రబీ కాలంలో శుక్రవారం వరకు 567 లక్షల హెక్టరుల విస్తీర్ణంలో సాగు పని పూర్తి అయింది .'},
#    '1070384': {'source': "ok google tweet mcdonald's down reseda has terrible service",
#     'target': 'సరే గూగుల్ ట్వీట్ మెక్\u200cడొనాల్డ్ డౌన్ రెసెడాలో భయంకరమైన సేవ ఉంది'},
#    '1070385': {'source': 'It is useful in making the skin bacteria free and at the same time it also makes the skin radiant .',
#     'target': 'చర్మాన్ని జీవాణు (రోగక్రిమి) రహితంగా చేయటంలో పసుపు పనికి వస్తుంది అంతేగాక అది చర్మాన్ని కాంతిమంతంగాకూడా చేస్తుంది .'},
#    '1070386': {'source': 'Hasimara Colony ` from Vuksha National Park is at a distance of 5 kilometres .',
#     'target': 'వృక్షములు జాతీయ ఉద్యానవనం జల్ పాయిగుడీ జిల్లా అంతర్గతముగా 117 కిలోమీటర్ల భూభాగంలో విస్తరించి ఉన్నది .'},
#    '1070387': {'source': 'Those you get blood in their gums , amla is very benefitial for them .',
#     'target': 'ఎవరి చిగురులలో రక్తం వస్తుందో , వారి కోసం అవిసె చాలా లాభదాయకమైనది .'},
#    '1070388': {'source': 'check my inbox', 'target': 'నా inbox చెక్ చెయ్యి'},
#    '1070389': {'source': 'Generally two types of deficiency come in muscles either their efficiency become less or with this their number decrease .',
#     'target': 'కండరాలలో సుమారు రెండు విధాల నష్టం వస్తుంది లేక అవి పరిణామం వల్ల తక్కువ అయిపోతాయి లేక దీనితోపాటు వాటి సంఖ్య తగ్గిపోతుంది .'},
#    '1070390': {'source': 'is kim kardashian married',
#     'target': 'మధులిక శర్మ వివాహం చేసుకున్నారా'},
#    '1070391': {'source': 'Jagannath Puri is special in several respects .',
#     'target': 'జగన్నాధుని పూరీ అనేక కోణాల నుండి సర్వ శ్రేష్ఠమైనది .'},
#    '1070392': {'source': 'Explosions in the mines create shivers in the environment of Amarkantak .',
#     'target': 'గనుల ప్రేలుళ్ళు అమర్\u200dకంటక్\u200d వాతావరణంలో గడ-గడ వణుకును పుట్టిస్తాయి .'},
#    '1070393': {'source': 'The Legislative Assembly consists of 404 members who are elected for five-year terms.',
#     'target': 'శాసనసభలో అయిదు సంవత్సరాల కాలానికి ఎన్నుకోబడిన 404 మంది సభ్యులు ఉంటారు.'},
#    '1070394': {'source': 'Fires were also reported in Dallas, Denton, and Collin counties.',
#     'target': 'డల్లాస్, డెంటన్, కొలిన్ కౌంటీలలో కూడా మంటలు చెలరేగాయి.'},
#    '1070395': {'source': 'give me the time in london',
#     'target': 'నాకు ఢిల్లీలో సమయం ఇవ్వండి'},
#    '1070396': {'source': 'It is said that several battles were fought in the Nandi mountain range .',
#     'target': 'నంది పర్వతమాలలో చాలా యుద్ధాలు చేసిందని చెప్పబడుతుంది .'},
#    '1070397': {'source': 'Parashar lake is located at a height of 4700 metres in the north - east 40 kms from Mandi Nagar and is spread in an area of half a km .',
#     'target': 'పారాశర్ సరస్సు , మంఢీ నగర్ నుండి 40 కిలోమీటర్లు దూరం ఈశాన్యంలో 4,700 మీటర్ల ఎత్తులో ఉన్నది మరియు సగం కిలోమీటర్ల క్షేత్రంలో వ్యాపించి ఉంది .'},
#    '1070398': {'source': 'For your cardio treatment walk quickly on the treadmill , do not run , if you want to run then run on the soft surface like soil of the garden or sand on the bank of water body .',
#     'target': 'మీ గుండె చికిత్స కోసం ట్రెడ్\u200dమిల్ పైన వేగంగా నడవండి , పరిగెత్తవద్దు ఒకవేళ మీరు పరిగెత్తాలనుకుంటే మెత్తనైన భూమిపై అది వనాల మట్టి లేక నీటి అంచుల ఇసుకపై పరిగెత్తండి .'},
#    '1070399': {'source': 'In 1946, the Basketball Association of America was formed.',
#     'target': '1946లో బాస్కెట్బాల్ అసోసియేషన్ ఆఫ్ అమెరికా ఏర్పడింది.'},
#    '1070400': {'source': 'Ambedkar published his book Annihilation of Caste on 15 May 1936.',
#     'target': 'అంబేద్కర్ 1936 మే 15వ తేదీన అనిహిలేషన్ ఆఫ్ కాస్ట్ అనే పుస్తకాన్ని ప్రచురించారు.'},
#    '1070401': {'source': 'The disease which spread through the microbes related to water .',
#     'target': 'నీళ్ళకు సంబంధించిన బ్యాక్టిరియా ద్వారా వ్యాపించే వ్యాధి .'},
#    '1070402': {'source': 'The first in the eastern tract consisting of 14 districts which are subject to periodical floods and droughts have been classified as scarcity areas.',
#     'target': 'మొదటిది, 14 జిల్లాలతో కూడిన తూర్పు భూభాగంలో వరదలు, కరువులు అప్పుడప్పుడు సంభవించే ప్రాంతాలను దుర్భిక్ష ప్రాంతాలుగా వర్గీకరించారు.'},
#    '1070403': {'source': 'Termite attack mint plants when the farm is not moist.',
#     'target': 'పొలంలో తడి లేనప్పుడు పుదీనా మొక్కలమీద చెదలయొక్క ఆక్రమణ జరుగుతుంది .'},
#    '1070404': {'source': 'On the way he also had to face some snowy storms at some places but he never gave up .',
#     'target': 'దారిలో వారు కొన్ని ప్రాదేశాలలో మంచుతుఫానులను కూడా ఎదురుకోవాల్సి వచ్చింది కానీ వారు ధైర్యాన్నిమాత్రం కోల్పోలేదు .'},
#    '1070405': {'source': 'tell me the office address of my brother',
#     'target': 'నా అన్న కార్యాలయ చిరునామా నాకు చెప్పు'},
#    '1070406': {'source': 'Roadways - Bhagalpur 50 kms , Nathanagar - 54 kms .',
#     'target': 'రోడ్డుమార్గం - భాగల్పూర్ 50 కిలోమీటర్లు , నాధ్ నగరము - 54 కిలోమీటర్లు .'},
#    '1070407': {'source': 'Before washing your feet kindly ensure that water is not extremely hot .',
#     'target': 'కాళ్ళు కడగటానికి ముందుగా దయచేసి నీళ్ళు ఎక్కువ వేడిగా ఉండరాదు అని నిశ్చయించుకోండి .'},
#    '1070408': {'source': 'The forests of Serohi National Park are dry , wet , evergreen and semi-evergreen .',
#     'target': 'సిరోహీ జాతీయ ఉద్యానవనం శీతోష్ణస్థితి ఎండ తక్కువగా ఉంటుంది .'},
#    '1070409': {'source': 'From her film ` Kalbela ` Pauli made her recognition in the industry .',
#     'target': 'తన చిత్రం ’కాల్\u200dబేలా’ నుంచి పావోలీ ఇండస్ట్రీలో గుర్తింపును తెచ్చుకుంది .'},
#    '1070410': {'source': 'From the SRI techniques in the paddy cultivation there is need of seeds from the rate of 2 kilograms per acre and some plants by the rate of 25-25 centimeter area per unit .',
#     'target': 'ఎస్.ఆర్.ఐ. సాంకేతికతతో వరిసాగులో ప్రతి ఎకరాకు 2 కిలోగ్రాముల చొప్పున విత్తనాలు మరియు ప్రతి ప్రమాణానికి 20-25 సెం.మీ.ల విస్తీర్ణం చొప్పున కొన్ని మొక్కల ఆవశ్యకత ఉంటుంది .'},
#    '1070411': {'source': 'According to witnesses, Patel read the note, pocketed it, and continued his cross-examination and won the case.',
#     'target': 'సాక్షుల కథనం ప్రకారం, పటేల్ నోట్ చదివి, దానిని జేబులో పెట్టుకొని, తన విచారణను కొనసాగించి కేసును గెలుచుకున్నాడు.'},
#    '1070412': {'source': 'The number of females among them is more .',
#     'target': 'దీనిలో పెద్ద సంఖ్య మహిళలదే .'},
#    '1070413': {'source': 'Products of dry flowers can be made anytime , this is why there sin o requirement of special climate or temperature .',
#     'target': 'ఎండిన పూల యొక్క ఉత్పత్తిని ఎప్పుడైనా చేయవచ్చు , దీని కోసం ఏ ప్రత్యేకమైన వాతావరణ లేదా ఉష్ణోగ్రత యొక్క అవసరం ఉండదు .'},
#    '1070414': {'source': "what's kim kardashian's measurements",
#     'target': 'కిమ్ కర్దాషియాన్ యొక్క కొలతలు ఏమిటి'},
#    '1070415': {'source': 'From Gorumara National Park the rail head Chalsa is 13 kilometres away .',
#     'target': 'గోరుమారా జాతీయ ఉద్యానవనం జలపాయిగుడీ జిల్లాలో 79 చదరపు కిలోమీటర్లలో స్దాపించడమైనది .'},
#    '1070416': {'source': 'In the opinion of natural therapy during this therapy one is inspired to cry .',
#     'target': 'ప్రకృతిపరమైన చికిత్స సూచనలో ఇటువంటి చికిత్స ఏడ్వటానికి ప్రేరేపిస్తుంది .'},
#    '1070417': {'source': 'You will get rid of insomnia .',
#     'target': 'అతినిద్ర నుంచి విముక్తి కలుగుతుంది .'},
#    '1070418': {'source': 'In shooting sports, revolvers and semi-automatic pistols are the most commonly used.',
#     'target': 'షూటింగ్ క్రీడలలో సర్వసాధారణంగా రివాల్వర్లు, సెమీ ఆటోమేటిక్ పిస్టళ్లు ఉపయోగిస్తారు.'},
#    '1070419': {'source': 'arrange and play all songs of eminem',
#     'target': 'చక్రి యొక్క అన్ని పాటలను అమర్చండి మరియు ప్లే చేయండి'},
#    '1070420': {'source': 'set first week of june as holiday in my calendar',
#     'target': 'నా క్యాలెండర్\u200cలో జూన్ మొదటి వారాన్ని సెలవు దినం గా సెట్ చేసాను'},
#    '1070421': {'source': 'was it windy yesterday',
#     'target': 'నిన్న గాలులు వున్నాయా'},
#    '1070422': {'source': 'The animals found in Namdapha National Park are tiger , leopard , Lam Cheetah , snow leopard , wild buffalo , Gaur ( a kind of wild buffalo ) , elephant , bear , Sambhar deer , Kakad ( barking deer ) , shy-cat , Hulak , Gibbon , Red Panda , and rare animals like bear-cat , musk deer Goral and Takin .',
#     'target': 'నమద్ఫా జాతీయ ఉద్యానవనంలో కనిపించేటువంటి జంతువులు పెద్దపులి , చిరుతపులి , మంచు చిరుతపులి , ( లమ్ చిరుతపులి ) , చిరుతపులి అడవి దున్న , అడవి ఎద్దు , ఏనుగు , ఎలుగుబంటి , సాంబర్ , కాకడ్ , పునుగు పిల్లి , హుల్కా గిబ్బిన్ , ఎర్రపాండా , కురుల పిల్లి మరియు కస్తూరి మృగం , గొరిల్లా మరియు జిరాఫీ లాంటి అరుదైన జంతువులు ఉన్నాయి .'},
#    '1070423': {'source': 'open inbox to check unread mails',
#     'target': 'చదవని మెయిల్స్ పరిశీలించడం కోసం ఇన్ బాక్స్ తెరువు'},
#    '1070424': {'source': 'lets get something on the calendar for tuesday',
#     'target': 'మంగళవారం ఏదైనా పంచాంగంలో పొందండి'},
#    '1070425': {'source': 'Nature has decorated the land of Kashmir with immense beauty .',
#     'target': 'ప్రకృతి కాశ్మీర్ భూమిని వెలకట్టలేని సౌందర్యంతో అలంకరించింది .'},
#    '1070426': {'source': 'The seminal vesicles of men may get destroyed .',
#     'target': 'పురుషులలో శుక్రకణాలకు నష్టం కలుగుతుంది .'},
#    '1070427': {'source': 'Five to ten drops of medicine for the adults every 4 hours with one spoon of water .',
#     'target': 'ఐదు నుంచి పది చుక్కల ఔషధాన్ని యువకులకు ప్రతి 4 గంటలకు ఒక స్పూను నీటి తోపాటు .'},
#    '1070428': {'source': 'Besides, he also used the family epithets Shri-prithvi-vallabha, Vallabha, and Shri-vallabha.',
#     'target': 'అంతేకాకుండా, ఆయన శ్రీ-పృథ్వీ-వల్లభ, వల్లభ, శ్రీ-వల్లభ అనే కుటుంబ బిరుదులను కూడా వాడుకున్నారు.'},
#    '1070429': {'source': 'These chants are complex, often recitations of sacred texts or in celebration of various festivals.',
#     'target': 'ఈ శ్లోకాలు సంక్లిష్టంగా ఉంటాయి, తరచుగా పవిత్ర గ్రంథాల పఠనం లేదా వివిధ పండుగ వేడుకలలో వీటి ఉచ్ఛారణ ఉంటాయి.'},
#    '1070430': {'source': 'shuffle and play all songs by gavenda artist',
#     'target': 'ఆ ర్ రెహ్మాన్ కళాకారుడు ద్వారా అన్ని పాటలు షఫుల్ చేయండి మరియు ప్లే చేయండి'},
#    '1070431': {'source': 'Here ion the day of Raksha Bandhan thrilling war of bagwaal or stones take place .',
#     'target': 'ఇక్కడ రాఖీ పండుగ రోజు బగవాల్ అనే రాళ్ళ ఉత్తేజపూరిత యుద్దం ఉంటుంది .'},
#    '1070432': {'source': 'turn the living rooms lights off',
#     'target': 'గదిలో లైట్లు ఆఫ్ చేయండి'},
#    '1070433': {'source': 'There is lot of benefit in sarasam balgami by pouring this decoction over head or keeping on forehead a bandage on soaking in it .',
#     'target': 'ఈ కషాయాన్ని తల పై వేయడం లేదా పట్టీ తడిపి తల పై ఉంచడం వలన సరసామ్ మెదడు పొరలవాపు బల్గమీలో చాలా ప్రయోజనం ఉంటుంది .'},
#    '1070434': {'source': 'The spreading of education among handicapped people is increasing due to the efforts of Indian government , state governments and self help organizations .',
#     'target': 'భారత ప్రభుత్వం , రాష్ట్ర ప్రభుత్వాలు మరియు స్వయంసేవా సంస్థల ప్రయత్నంతో వికలాంగులలో విద్య వ్యాప్తి పెరుగుతోంది .'},
#    '1070435': {'source': 'Hotels and guest houses in a large number are available here .',
#     'target': 'ఇక్కడ పెద్ద సంఖ్యలో హోటళ్ళు , అతిథి గృహాలు మొదలగునవి లభిస్తాయి .'},
#    '1070436': {'source': 'turn the room light off',
#     'target': 'గది లైట్ ఆఫ్ మార్చు చేయండి'},
#    '1070437': {'source': 'For the good production of maize it is required to put adequate amount of fertilizers .',
#     'target': 'మొక్కజొన్న అధిక దిగుబడి కారణమైన రసాయనిక ఎరువులను తగిన పరిమాణంలోనే వేయవలసి ఉంటుంది .'},
#    '1070438': {'source': 'It is used in a variety of ways .',
#     'target': 'ఇది పూర్తిగా ఉపయోగింపబడుతుంది .'},
#    '1070439': {'source': 'The reservoir was formed by the construction of the Tawa Dam, which began in 1958 and was completed in 1978.',
#     'target': '1958లో ప్రారంభమై 1978లో పూర్తయిన తవా డ్యామ్ నిర్మాణంతో ఈ రిజర్వాయర్ ఏర్పడింది.'},
#    ...}}}

# %%
f = open("answer.txt", "r")
for x in f:
  print(x)

# %%
import csv 
import json
 
with open('train_data1.json') as user_file:
  parsed_json = json.load(user_file)

import csv 
    

# field names 
#fields = ['english_sentence', 'hindi_sentence'] 
filename = "English_Malayalam.csv"
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
    # writing the fields 
 #   csvwriter.writerow(fields) 
        
    # writing the data rows 
    for i in range(812759+1-758703):
        x = 758703+i
        csvwriter.writerows([[parsed_json["English-Malayalam"]["Train"][str(x)]["source"],parsed_json["English-Malayalam"]["Train"][str(x)]["target"]]])

# %%
import csv 
import json
 
with open('test_data1.json') as user_file:
  parsed_json = json.load(user_file)

import csv 
    

# field names 
#fields = ['english_sentence', 'hindi_sentence'] 
filename = "English_Bengali.csv"
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
    # writing the fields 
 #   csvwriter.writerow(fields) 
        
    # writing the data rows 
    for i in range(976432+1-918072):
        x = 918072+i
        csvwriter.writerows([[parsed_json["English-Bengali"]["Train"][str(x)]["source"],parsed_json["English-Bengali"]["Train"][str(x)]["target"]]])

# %%
# ,,,,,
# 225.0,maya,3.0,disgust,kya kya bhar ke rakha hai indravadan ne is ghar mein indravadan please tum sari bekar ki chijen bahar kyon nahin fekte?,0
# ,,,,,
# 226.0,maya,3.0,disgust,kya kya bhar ke rakha hai indravadan ne is ghar mein indravadan please tum sari bekar ki chijen bahar kyon nahin fekte?,0
# 226.0,indu,1.0,contempt,"ok, chalo rosesh chalo bahar",0
import csv 
import json
 
with open('train_data1.json') as user_file:
  parsed_json = json.load(user_file)

import csv 
    

# field names 
#fields = ['english_sentence', 'hindi_sentence'] 
filename = "English_Telgu.csv"
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
    # writing the fields 
 #   csvwriter.writerow(fields) 
        
    # writing the data rows 
    for i in range(1114344+1-1069440):
        x = 1069440+i
        csvwriter.writerows([[parsed_json["English-Telgu"]["Train"][str(x)]["source"],parsed_json["English-Telgu"]["Train"][str(x)]["target"]]])

# %%
import json
 
with open('test_data1.json') as user_file:
  parsed_json = json.load(user_file)

import csv 
    
# field names 
 
filename = "English_Bengali_test.csv"
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
        
    # writing the data rows 
    for i in range(196710-177039+1):
        x = 177039+i
        csvwriter.writerows([[parsed_json["English-Bengali"]["Test"][str(x)]["source"]]])

# %%
import json
 
with open('test_data1.json') as user_file:
  parsed_json = json.load(user_file)

import csv 
    
# field names 
 
filename = "English_Gujarati_test.csv"
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
        
    # writing the data rows 
    for i in range(332374-318808+1):
        x = 318808+i
        csvwriter.writerows([[parsed_json["English-Gujarati"]["Test"][str(x)]["source"]]])

# %%
import json
 
with open('test_data1.json') as user_file:
  parsed_json = json.load(user_file)

import csv 
    
# field names 
 
filename = "English_Hindi_test.csv"
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
        
    # writing the data rows 
    for i in range(563223-540139+1):
        x = 540139+i
        csvwriter.writerows([[parsed_json["English-Hindi"]["Test"][str(x)]["source"]]])

# %%
import json
 
with open('test_data1.json') as user_file:
  parsed_json = json.load(user_file)

import csv 
    
# field names 
 
filename = "English_Kannada_test.csv"
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
        
    # writing the data rows 
    for i in range(696923-683553+1):
        x = 683553+i
        csvwriter.writerows([[parsed_json["English-Kannada"]["Test"][str(x)]["source"]]])

# %%
import json
 
with open('test_data1.json') as user_file:
  parsed_json = json.load(user_file)

import csv 
    
# field names 
 
filename = "English_Malayalam_test.csv"
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
        
    # writing the data rows 
    for i in range(851373-835928+1):
        x = 835928+i
        csvwriter.writerows([[parsed_json["English-Malayalam"]["Test"][str(x)]["source"]]])

# %%
import json
 
with open('test_data1.json') as user_file:
  parsed_json = json.load(user_file)

import csv 
    
# field names 
 
filename = "English_Tamil_test.csv"
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
        
    # writing the data rows 
    for i in range(1018120-1001446+1):
        x = 1001446+i
        csvwriter.writerows([[parsed_json["English-Tamil"]["Test"][str(x)]["source"]]])

# %%
import json
 
with open('test_data1.json') as user_file:
  parsed_json = json.load(user_file)

import csv 
    
# field names 
 
filename = "English_Telgu_test.csv"
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
        
    # writing the data rows 
    for i in range(1146420-1133590+1):
        x = 1133590+i
        csvwriter.writerows([[parsed_json["English-Telgu"]["Test"][str(x)]["source"]]])

# %%
import json
 
with open('val_data1.json') as user_file:
  parsed_json = json.load(user_file)

len(parsed_json["English-Bengali"]["Validation"])+len(parsed_json["English-Gujarati"]["Validation"])+len(parsed_json["English-Hindi"]["Validation"])+len(parsed_json["English-Kannada"]["Validation"])+len(parsed_json["English-Malayalam"]["Validation"])+len(parsed_json["English-Telgu"]["Validation"])+len(parsed_json["English-Tamil"]["Validation"])
# Out:
# 57323

# %%
import json
 
with open('val_data1.json') as user_file:
  parsed_json = json.load(user_file)

import csv 
    
# field names 
 
filename = "English_Tamil_val.csv"
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
        
    # writing the data rows 
    for i in range(984770-976433+1):
        x = 976433+i
        csvwriter.writerows([[parsed_json["English-Tamil"]["Validation"][str(x)]["source"]]])

# %%
import json
 
with open('val_data1.json') as user_file:
  parsed_json = json.load(user_file)

import csv 
    
# field names 
 
filename = "English_Telgu_val.csv"
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
        
    # writing the data rows 
    for i in range(1120759-1114345+1):
        x = 1114345+i
        csvwriter.writerows([[parsed_json["English-Telgu"]["Validation"][str(x)]["source"]]])

# %%
#######################################################
#               Load Data and Pre-process
#######################################################

#1. We will load the csv and remove the source column as it is not needed
#2. We remove the duplicates in the data if any
#3. Preprocess the data to remove punctuations, digits, spaces and making the text lower.
#.  This helps reduce the vocab of the data (as now, "Cat ~" is "cat")

#load data
data = pd.read_csv('english_hindi.csv')
# data = data.reset_index(drop=True)
# data.drop('source',axis=1,inplace=True)

#preprocess
data = data.dropna().drop_duplicates()

#lower and remove quotes
data['english_sentence'] = data.english_sentence.parallel_apply(lambda x: re.sub("'", '',x).lower())
data['hindi_sentence'] = data.hindi_sentence.parallel_apply(lambda x: re.sub("'", '', x).lower())
    
#remove special chars
exclude = set(string.punctuation)#set of all special chars
#remove all the special chars
data['english_sentence'] = data.english_sentence.parallel_apply(lambda x: ''.join(ch for ch in x if ch not in exclude))
data['hindi_sentence'] = data.hindi_sentence.parallel_apply(lambda x: ''.join(ch for ch in x if ch not in exclude))
    
remove_digits = str.maketrans('','',digits)
data['english_sentence'] = data.english_sentence.parallel_apply(lambda x: x.translate(remove_digits))
data['hindi_sentence'] = data.hindi_sentence.parallel_apply(lambda x: x.translate(remove_digits))

data['hindi_sentence'] = data.hindi_sentence.parallel_apply(lambda x: re.sub("[२३०८१५७९४६]","",x))


# Remove extra spaces
data['english_sentence']=data['english_sentence'].parallel_apply(lambda x: x.strip())
data['hindi_sentence']=data['hindi_sentence'].parallel_apply(lambda x: x.strip())
data['english_sentence']=data['english_sentence'].parallel_apply(lambda x: re.sub(" +", " ", x))
data['hindi_sentence']=data['hindi_sentence'].parallel_apply(lambda x: re.sub(" +", " ", x))

# %%
#######################################################
#               Create Train and Valid sets 
#######################################################

val_frac = 0.1 #precentage data in val
val_split_idx = int(len(data)*val_frac) #index on which to split
data_idx = list(range(len(data))) #create a list of ints till len of data
np.random.shuffle(data_idx)

#get indexes for validation and train
val_idx, train_idx = data_idx[:val_split_idx], data_idx[val_split_idx:]
print('len of train: ', len(train_idx))
print('len of val: ', len(val_idx))

#create the sets
train = data.iloc[train_idx].reset_index().drop('index',axis=1)
val = data.iloc[val_idx].reset_index().drop('index',axis=1)
# Out:
# len of train:  72176
# len of val:  8019

# %%
#######################################################
#               Define Vocabulary Class
#######################################################

class Vocabulary:
  
    '''
    __init__ method is called by default as soon as an object of this class is initiated
    we use this method to initiate our vocab dictionaries
    '''
    def __init__(self, freq_threshold, max_size):
        '''
        freq_threshold : the minimum times a word must occur in corpus to be treated in vocab
        max_size : max source vocab size. Eg. if set to 10,000, we pick the top 10,000 most frequent words and discard others
        '''
        #initiate the index to token dict
        ## <PAD> -> padding, used for padding the shorter sentences in a batch to match the length of longest sentence in the batch
        ## <SOS> -> start token, added in front of each sentence to signify the start of sentence
        ## <EOS> -> End of sentence token, added to the end of each sentence to signify the end of sentence
        ## <UNK> -> words which are not found in the vocab are replace by this token
        self.itos = {0: '<PAD>', 1:'<SOS>', 2:'<EOS>', 3: '<UNK>'}
        #initiate the token to index dict
        self.stoi = {k:j for j,k in self.itos.items()} 
        
        self.freq_threshold = freq_threshold
        self.max_size = max_size
    
    '''
    __len__ is used by dataloader later to create batches
    '''
    def __len__(self):
        return len(self.itos)
    
    '''
    a simple tokenizer to split on space and converts the sentence to list of words
    '''
    @staticmethod
    def tokenizer(text):
        return [tok.lower().strip() for tok in text.split(' ')]
    
    '''
    build the vocab: create a dictionary mapping of index to string (itos) and string to index (stoi)
    output ex. for stoi -> {'the':5, 'a':6, 'an':7}
    '''
    def build_vocabulary(self, sentence_list):
        #calculate the frequencies of each word first to remove the words with freq < freq_threshold
        frequencies = {}  #init the freq dict
        idx = 4 #index from which we want our dict to start. We already used 4 indexes for pad, start, end, unk
        
        #calculate freq of words
        for sentence in sentence_list:
            for word in self.tokenizer(sentence):
                if word not in frequencies.keys():
                    frequencies[word]=1
                else:
                    frequencies[word]+=1
                    
                    
        #limit vocab by removing low freq words
        frequencies = {k:v for k,v in frequencies.items() if v>self.freq_threshold} 
        
        #limit vocab to the max_size specified
        frequencies = dict(sorted(frequencies.items(), key = lambda x: -x[1])[:self.max_size-idx]) # idx =4 for pad, start, end , unk
            
        #create vocab
        for word in frequencies.keys():
            self.stoi[word] = idx
            self.itos[idx] = word
            idx+=1
            
    '''
    convert the list of words to a list of corresponding indexes
    '''    
    def numericalize(self, text):
        #tokenize text
        tokenized_text = self.tokenizer(text)
        numericalized_text = []
        for token in tokenized_text:
            if token in self.stoi.keys():
                numericalized_text.append(self.stoi[token])
            else: #out-of-vocab words are represented by UNK token index
                numericalized_text.append(self.stoi['<UNK>'])
                
        return numericalized_text

# %%
#create a vocab class with freq_threshold=0 and max_size=100
voc = Vocabulary(0, 100)
sentence_list = ['that is a cat', 'that is not a dog']
#build vocab
voc.build_vocabulary(sentence_list)

print('index to string: ',voc.itos)
print('string to index:',voc.stoi)

print('numericalize -> cat and a dog: ', voc.numericalize('cat and a dog'))
# Out:
# index to string:  {0: '<PAD>', 1: '<SOS>', 2: '<EOS>', 3: '<UNK>', 4: 'that', 5: 'is', 6: 'a', 7: 'cat', 8: 'not', 9: 'dog'}
# string to index: {'<PAD>': 0, '<SOS>': 1, '<EOS>': 2, '<UNK>': 3, 'that': 4, 'is': 5, 'a': 6, 'cat': 7, 'not': 8, 'dog': 9}
# numericalize -> cat and a dog:  [7, 3, 6, 9]

# %%
#######################################################
#               Define Train_Dataset class
#######################################################

class Train_Dataset(Dataset):
    '''
    Initiating Variables
    df: the training dataframe
    source_column : the name of source text column in the dataframe
    target_columns : the name of target text column in the dataframe
    transform : If we want to add any augmentation
    freq_threshold : the minimum times a word must occur in corpus to be treated in vocab
    source_vocab_max_size : max source vocab size
    target_vocab_max_size : max target vocab size
    '''
    
    def __init__(self, df, source_column, target_column, transform=None, freq_threshold = 5,
                source_vocab_max_size = 10000, target_vocab_max_size = 10000):
    
        self.df = df
        self.transform = transform
        
        #get source and target texts
        self.source_texts = self.df[source_column]
        self.target_texts = self.df[target_column]
        
        
        ##VOCAB class has been created above
        #Initialize source vocab object and build vocabulary
        self.source_vocab = Vocabulary(freq_threshold, source_vocab_max_size)
        self.source_vocab.build_vocabulary(self.source_texts.tolist())
        #Initialize target vocab object and build vocabulary
        self.target_vocab = Vocabulary(freq_threshold, target_vocab_max_size)
        self.target_vocab.build_vocabulary(self.target_texts.tolist())
        
    def __len__(self):
        return len(self.df)
    
    '''
    __getitem__ runs on 1 example at a time. Here, we get an example at index and return its numericalize source and
    target values using the vocabulary objects we created in __init__
    '''
    def __getitem__(self, index):
        source_text = self.source_texts[index]
        target_text = self.target_texts[index]
        
        if self.transform is not None:
            source_text = self.transform(source_text)
            
        #numericalize texts ['<SOS>','cat', 'in', 'a', 'bag','<EOS>'] -> [1,12,2,9,24,2]
        numerialized_source = [self.source_vocab.stoi["<SOS>"]]
        numerialized_source += self.source_vocab.numericalize(source_text)
        numerialized_source.append(self.source_vocab.stoi["<EOS>"])
    
        numerialized_target = [self.target_vocab.stoi["<SOS>"]]
        numerialized_target += self.target_vocab.numericalize(target_text)
        numerialized_target.append(self.target_vocab.stoi["<EOS>"])
        
        #convert the list to tensor and return
        return torch.tensor(numerialized_source), torch.tensor(numerialized_target)

# %%
train_dataset = Train_Dataset(train, 'english_sentence', 'hindi_sentence')
print(train.loc[1])
train_dataset[1]
# Out:
# english_sentence    according to the national human rights commiss...
# hindi_sentence      भारतीय राष्ट्रीय मानवाधिकार आयोग एनएचआरसी के अ...
# Name: 1, dtype: object
# (tensor([   1,  208,    8,    4,  113,  536, 3633, 3234,    5,   54,    3,  872,
#           249, 6948,    4,  122,    5,  276,    5, 4976,    3,    6,    3, 1530,
#             2]),
#  tensor([   1,  158,  279,    3, 3523,    3,    4,  228,  242,  235,    3,   10,
#             3,    5, 4179,    7,  181,    5,   59,  292,   15,    2]))

# %%
#######################################################
#               Define Dataset Class
#######################################################

class Validation_Dataset:
    def __init__(self, train_dataset, df, source_column, target_column, transform = None):
        self.df = df
        self.transform = transform
        
        #train dataset will be used as lookup for vocab
        self.train_dataset = train_dataset
        
        #get source and target texts
        self.source_texts = self.df[source_column]
        self.target_texts = self.df[target_column]
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self,index):
        source_text = self.source_texts[index]
        #print(source_text)
        target_text = self.target_texts[index]
        #print(target_text)
        if self.transform is not None:
            source_text = self.transform(source_text)
            
        #numericalize texts ['<SOS>','cat', 'in', 'a', 'bag','<EOS>'] -> [1,12,2,9,24,2]
        numerialized_source = [self.train_dataset.source_vocab.stoi["<SOS>"]]
        numerialized_source += self.train_dataset.source_vocab.numericalize(source_text)
        numerialized_source.append(self.train_dataset.source_vocab.stoi["<EOS>"])
    
        numerialized_target = [self.train_dataset.target_vocab.stoi["<SOS>"]]
        numerialized_target += self.train_dataset.target_vocab.numericalize(target_text)
        numerialized_target.append(self.train_dataset.target_vocab.stoi["<EOS>"])
        #print(numerialized_source)
        return torch.tensor(numerialized_source), torch.tensor(numerialized_target)

# %%
#######################################################
#               Collate fn
#######################################################

'''
class to add padding to the batches
collat_fn in dataloader is used for post processing on a single batch. Like __getitem__ in dataset class
is used on single example
'''

class MyCollate:
    def __init__(self, pad_idx):
        self.pad_idx = pad_idx
        
    
    #__call__: a default method
    ##   First the obj is created using MyCollate(pad_idx) in data loader
    ##   Then if obj(batch) is called -> __call__ runs by default
    def __call__(self, batch):
        #get all source indexed sentences of the batch
        source = [item[0] for item in batch] 
        #pad them using pad_sequence method from pytorch. 
        source = pad_sequence(source, batch_first=False, padding_value = self.pad_idx) 
        
        #get all target indexed sentences of the batch
        target = [item[1] for item in batch] 
        #pad them using pad_sequence method from pytorch. 
        target = pad_sequence(target, batch_first=False, padding_value = self.pad_idx)
        return source, target

# %%
#######################################################
#            Define Dataloader Functions
#######################################################

# If we run a next(iter(data_loader)) we get an output of batch_size * (num_workers+1)
def get_train_loader(dataset, batch_size, num_workers=0, shuffle=True, pin_memory=True): #increase num_workers according to CPU
    #get pad_idx for collate fn
    pad_idx = dataset.source_vocab.stoi['<PAD>']
    #define loader
    loader = DataLoader(dataset, batch_size = batch_size, num_workers = num_workers,
                        shuffle=shuffle,
                       pin_memory=pin_memory, collate_fn = MyCollate(pad_idx=pad_idx)) #MyCollate class runs __call__ method by default
    return loader

def get_valid_loader(dataset, train_dataset, batch_size, num_workers=0, shuffle=True, pin_memory=True):
    pad_idx = train_dataset.source_vocab.stoi['<PAD>']
    loader = DataLoader(dataset, batch_size = batch_size, num_workers = num_workers,
                        shuffle=shuffle,
                       pin_memory=pin_memory, collate_fn = MyCollate(pad_idx=pad_idx))
    return loader

# %%
train_loader = get_train_loader(train_dataset, 32)
source = next(iter(train_loader))[0]
target = next(iter(train_loader))[1]

print('source: \n', source)

print('source shape: ',source.shape)
print('target shape: ', target.shape)
# Out:
# source:
#  tensor([[   1,    1,    1,  ...,    1,    1,    1],
#         [2485,    4,    4,  ...,   12,  178,  137],
#         [1302,  446,  846,  ...,    9,    3,    8],
#         ...,
#         [   0,    0,    4,  ...,    0,    0,    0],
#         [   0,    0,    3,  ...,    0,    0,    0],
#         [   0,    0,    2,  ...,    0,    0,    0]])
# source shape:  torch.Size([38, 32])
# target shape:  torch.Size([47, 32])
